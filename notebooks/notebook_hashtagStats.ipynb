# %% [markdown]
# ########################################################################################

# %% [markdown]
# ## Upsert hashtagStats

# %% [markdown]
# ########################################################################################

# %% [markdown]
# ## (optional) libraries in trigger function

# %%
import pymongo # connect to MongoDB
from pymongo import MongoClient
from IPython.display import clear_output # clear output everytime running
from pprint import pprint

# %% [markdown]
# ## mandatory libraries in trigger function

# %%
import json
import sys
# from mongo_client import mongo_client
from bson.objectid import ObjectId
from bson import regex
from datetime import datetime, timedelta
import re
import math

# %%
# connect to MongoDB
## define connection URI as role; analytics-admin
connectionUri = 'mongodb+srv://analytics-admin:pnYT55BGWwHePK1M@dev-cluster.fg2e5.mongodb.net/myFirstDatabase?retryWrites=true&w=majority'

## assign client
client = pymongo.MongoClient(connectionUri)

## assign databases
appDb = client['app-db']
analyticsDb = client['analytics-db']

## assign collections
### source collections
contents = appDb['contents']

### destination collections
userStats = analyticsDb['userStats']
hashtagStats = analyticsDb['hashtagStats']

# %% [markdown]
# ########################################################################################

# %% [markdown]
# ########################################################################################

# %% [markdown]
# ## Hashtag parsing

# %% [markdown]
# ### note!!!: Be careful! running this cell cause collection changes

# %% [markdown]
# ### below cell just for filtering in testing

# %%
# define RegEx
namepattern = regex.Regex.from_native(re.compile(r"(?<=#)\w+"))
namepattern.flags ^= re.UNICODE

tagpattern = regex.Regex.from_native(re.compile(r"#\w+"))
tagpattern.flags ^= re.UNICODE

# %%
# define RegEx
pattern = regex.Regex.from_native(re.compile(r"(?<=#)\w+"))
pattern.flags ^= re.UNICODE

# define content parameters
contentDateThreshold = 14
likedWeight = 1
commentedWeight = 1
recastedWeight = 1
quotedWeight = 1
halfLifeHours = 24

# %%
# define cursor
cursor = [
    {
        # filter contents for newer than specific age
        '$match': {
            'createdAt': {
                '$gte': (datetime.utcnow() - timedelta(days=contentDateThreshold)) 
                }
        }
#     }, {
#             # !!! TESTING filter
#         '$match': {
#             'payload.message': {
#                     '$regex': tagpattern
#                 }
#         }
    }, {
        # extract hashtag => array
        '$addFields': {
            'hashtags': {
                '$regexFindAll': {
                    'input': '$payload.message', 
                    'regex': pattern
                }
            }
        }
    }, {
        # deconstruct hashtags array => hashtag object
        '$unwind': {
            'path': '$hashtags', 
            'preserveNullAndEmptyArrays': True
        }
    }, {
        # extract hashtag object => field
        '$addFields': {
        'name': {
            '$toLower': '$hashtags.match'
            }
        }
    }, {
        # summarize by user (not account)
        # collect contentId as array
        '$group': {
            '_id': {
                'name': '$name',
                'authorId': '$author.id'
            }, 
            'contributionCount': {
                '$count': {}
            }, 
            'createdAt': {
                '$min': '$createdAt'
            }, 
            'updatedAt': {
                '$max': '$updatedAt'
            },
            'contents': {
                '$push': "$_id"
            },
            # ! follow app-db.hashtags schema
            '__v': {
                '$max': '$__v'
            },
            'likedCount': {
                '$sum': '$engagements.like.count'
            },
            'commentedCount': {
                '$sum': '$engagements.comment.count'
            },
            'recastedCount': {
                '$sum': '$engagements.recast.recast'
            },
            'quotedCount': {
                '$sum': '$engagements.quote.recast'
            }
        }
    }, {
        # summarize by hashtag
        '$group': {
            '_id': '$_id.name', 
            'hashtagCount': {
                '$sum': '$contributionCount'
            }, 
            'contributorCount': {'$count': {}},
            'createdAt': {
                '$min': '$createdAt'
            }, 
            'updatedAt': {
                '$max': '$updatedAt'
            },
            # ! follow app-db.hashtags schema
            '__v': {
                '$max': '$__v'
            },
            'contributions': {
                '$push': {
                    '_id': '$_id.authorId', 
                    'contributionCount': '$contributionCount', 
                    'contents': "$contents",
                }
            },
            'likedCount': {
                '$sum': '$likedCount'
            },
            'commentedCount': {
                '$sum': '$commentedCount'
            },
            'recastedCount': {
                '$sum': '$recastedCount'
            },
            'quotedCount': {
                '$sum': '$quotedCount'
            }
        }    
    }, {
        # setting output format
        '$project': {
            '_id': 0,  
            'name': '$_id',
            '__v': '$__v',
            'createdAt': 1, 
            'updatedAt': 1, 
            'aggregator.contributions': '$contributions',
            # calculate fraction of hashtag diversity
            ## equation: hastagDiversityScore = n_{user|hashtag}/n_{content|hashtag}
            'aggregator.hastagDiversityScore': {
                '$divide': [
                    '$contributorCount', '$hashtagCount'
                ]
            },
            # calculate linear combination of engagements 
            ## equation: engagementScore = {\sigma}_{k}({\beta}_{k}*x_{k})
            'aggregator.engagementScore': {
                '$sum': [
                    {
                        '$multiply': [
                            '$commentedCount', commentedWeight
                        ]
                    }, {
                        '$multiply': [
                            '$recastedCount', recastedWeight
                        ]
                    }, {
                        '$multiply': [
                            '$quotedCount', quotedWeight
                        ]
                    }, {
                        '$multiply': [
                            '$quotedCount', quotedWeight
                        ]
                    }
                ]
            },
            # calculate decay from last update time
            ## equation: ageScore = e^(-{\lambda}*t)
            'aggregator.ageScore': {
                '$exp': {
                    '$multiply': [
                        {
                            '$multiply': [
                                {
                                    # calculate age from last update time
                                    '$divide': [
                                        {
                                            '$subtract': [datetime.utcnow(), "$updatedAt"]
                                        }, 60*60*1000
                                    ]
                                }, {
                                    # define lambda value
                                    '$divide': [{'$ln': 2}, halfLifeHours]
                                }
                            ]
                        }, -1
                    ]
                }
            }            
        }
    }, {
        # summarize all scores
        ## equation: score = ageScore*(engagementScore + 1)*(hastagDiversityScore)
        '$addFields': {
            'score': {
                '$multiply': [
                    '$aggregator.hastagDiversityScore',
                    # add 1 as bias
                    {'$add': ['$aggregator.engagementScore', 1]},
                    '$aggregator.ageScore'
                ]
            }
        }   
#     }, {
#         # upsert to 'hashtagStats' collection
#         '$merge': {
#             'into': {
#                 'db': 'analytics-db', 
#                 'coll': 'hashtagStats'
#             }, 
#             'on': '_id', 
#             'whenMatched': 'replace', 
#             'whenNotMatched': 'insert'
#         }
    }
]

# %%
# clear the output
clear_output()

# print output
pprint(list(contents.aggregate(cursor)))
# Out:
# [{'__v': 0,
#   'aggregator': {'ageScore': 0.0441625540176349,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615ad8d5ae2035074d2d988f'),
#                                                  ObjectId('615b2d37ae203546822d9b51'),
#                                                  ObjectId('615b7a8dae2035647c2d9cf9'),
#                                                  ObjectId('615b7a8eae2035813c2d9d01'),
#                                                  ObjectId('615b8195ae20356d0b2d9d21'),
#                                                  ObjectId('615bd5f5ae20354c922d9e55'),
#                                                  ObjectId('615bd5f5ae20353e402d9e5d'),
#                                                  ObjectId('615c3865ae20350b232da08a'),
#                                                  ObjectId('615c3865ae203542ac2da092'),
#                                                  ObjectId('615c699dae203512f42da20e'),
#                                                  ObjectId('6161cbbda52e7261d217137d')],
#                                     'contributionCount': 11}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.09090909090909091},
#   'createdAt': datetime.datetime(2021, 10, 4, 10, 35, 1, 617000),
#   'name': 'mbapp',
#   'score': 0.004014777637966809,
#   'updatedAt': datetime.datetime(2021, 10, 9, 17, 5, 1, 956000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.0026052313341135285,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615c699dae20351eaf2da1fe')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 5, 15, 5, 1, 361000),
#   'name': 'arsenal',
#   'score': 0.0026052313341135285,
#   'updatedAt': datetime.datetime(2021, 10, 5, 15, 5, 1, 361000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.01186726751487123,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615f4be54f989b143f4c26c5')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 7, 19, 35, 1, 741000),
#   'name': 'deadlineday',
#   'score': 0.01186726751487123,
#   'updatedAt': datetime.datetime(2021, 10, 7, 19, 35, 1, 741000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.05894968509456912,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('6162585da52e72626c1714df')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 10, 3, 5, 1, 423000),
#   'name': 'mbap',
#   'score': 0.05894968509456912,
#   'updatedAt': datetime.datetime(2021, 10, 10, 3, 5, 1, 423000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.00027190092949880295,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61581d3e248bfd3830f84c9d'),
#                                                  ObjectId('61581d47248bfd5498f84cbd')],
#                                     'contributionCount': 2}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.5},
#   'createdAt': datetime.datetime(2021, 10, 2, 8, 50, 6, 186000),
#   'name': 'nftcollector',
#   'score': 0.00013595046474940148,
#   'updatedAt': datetime.datetime(2021, 10, 2, 8, 50, 15, 27000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.0002718945404430205,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61581d44248bfd5e83f84cb5')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 2, 8, 50, 12, 98000),
#   'name': 'sol',
#   'score': 0.0002718945404430205,
#   'updatedAt': datetime.datetime(2021, 10, 2, 8, 50, 12, 98000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.00028322509575006853,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61583125248bfdbd4cf84dc1')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 2, 10, 15, 1, 224000),
#   'name': '677',
#   'score': 0.00028322509575006853,
#   'updatedAt': datetime.datetime(2021, 10, 2, 10, 15, 1, 224000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.02305892271165007,
#                  'contributions': [{'_id': ObjectId('614addffec903a9d987eb580'),
#                                     'contents': [ObjectId('61608f56a52e72762d170f3b')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 8, 18, 35, 2, 86000),
#   'name': 'ballondor',
#   'score': 0.02305892271165007,
#   'updatedAt': datetime.datetime(2021, 10, 8, 18, 35, 2, 86000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.015141767006161164,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615fc28b4f989b35ec4c292e'),
#                                                  ObjectId('615fc28b4f989b35ec4c292e')],
#                                     'contributionCount': 2}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.5},
#   'createdAt': datetime.datetime(2021, 10, 8, 4, 1, 15, 297000),
#   'name': 'web3',
#   'score': 0.007570883503080582,
#   'updatedAt': datetime.datetime(2021, 10, 8, 4, 1, 15, 297000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.00029862686873993125,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('6155aef68bcb970c7b487228'),
#                                                  ObjectId('61584aed248bfd0116f84e9f')],
#                                     'contributionCount': 2}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.5},
#   'createdAt': datetime.datetime(2021, 9, 30, 12, 35, 2, 125000),
#   'name': 'koeman',
#   'score': 0.00014931343436996563,
#   'updatedAt': datetime.datetime(2021, 10, 2, 12, 5, 1, 741000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.1313276586826847,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('6163dcdc25d4854011fc98d3'),
#                                                  ObjectId('6163de6225d485c4b9fc990b')],
#                                     'contributionCount': 2}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.5},
#   'createdAt': datetime.datetime(2021, 10, 11, 6, 42, 36, 288000),
#   'name': 'be_active_be_earning',
#   'score': 0.06566382934134235,
#   'updatedAt': datetime.datetime(2021, 10, 11, 6, 49, 6, 540000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.044162590864404654,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('6155cb158bcb97856e48732c'),
#                                                  ObjectId('6161cbbea52e727fcb171385')],
#                                     'contributionCount': 2}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.5},
#   'createdAt': datetime.datetime(2021, 9, 30, 14, 35, 1, 307000),
#   'name': 'acmilan',
#   'score': 0.022081295432202327,
#   'updatedAt': datetime.datetime(2021, 10, 9, 17, 5, 2, 60000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.002265804601449975,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615c25a5ae20356cfd2da008')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 5, 10, 15, 1, 435000),
#   'name': '680',
#   'score': 0.002265804601449975,
#   'updatedAt': datetime.datetime(2021, 10, 5, 10, 15, 1, 435000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.01042100534412131,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615f0c9e16db7318c0a60217')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 7, 15, 5, 2, 318000),
#   'name': 'espa',
#   'score': 0.01042100534412131,
#   'updatedAt': datetime.datetime(2021, 10, 7, 15, 5, 2, 318000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.0026052324000425254,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615c699dae20357d3e2da206')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 5, 15, 5, 1, 412000),
#   'name': 'italia',
#   'score': 0.0026052324000425254,
#   'updatedAt': datetime.datetime(2021, 10, 5, 15, 5, 1, 412000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.0026052324000425254,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615c699dae20357d3e2da206')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 5, 15, 5, 1, 412000),
#   'name': 'ultraweave',
#   'score': 0.0026052324000425254,
#   'updatedAt': datetime.datetime(2021, 10, 5, 15, 5, 1, 412000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.0020628014870615937,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615bf7f1ae2035646b2d9eef')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 5, 7, 0, 1, 280000),
#   'name': 'huobiturns8',
#   'score': 0.0020628014870615937,
#   'updatedAt': datetime.datetime(2021, 10, 5, 7, 0, 1, 280000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.32869231997242543,
#                  'contributions': [{'_id': ObjectId('614addffec903a9d987eb580'),
#                                     'contents': [ObjectId('6156cf3e8bcb970b1f4878cd'),
#                                                  ObjectId('6157da6d248bfd6e11f84a7a'),
#                                                  ObjectId('615a614d248bfd282ef85440'),
#                                                  ObjectId('615d6dc6ae2035f4082da63f'),
#                                                  ObjectId('615e7ffddb45d0ef3f925ad9'),
#                                                  ObjectId('615fc36e4f989b78e14c293e'),
#                                                  ObjectId('6161cbbea52e720afd17138d'),
#                                                  ObjectId('6162666da52e7258b21714ef'),
#                                                  ObjectId('616491e617d8252b20079959'),
#                                                  ObjectId('61659d1681952a329b2c350b')],
#                                     'contributionCount': 10}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.1},
#   'createdAt': datetime.datetime(2021, 10, 1, 9, 5, 2, 125000),
#   'name': 'goaloftheday',
#   'score': 0.032869231997242544,
#   'updatedAt': datetime.datetime(2021, 10, 12, 14, 35, 2, 725000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.3057961166097747,
#                  'contributions': [{'_id': ObjectId('614addffec903a9d987eb580'),
#                                     'contents': [ObjectId('616579ee81952a3d5f2c33bf')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 12, 12, 5, 2, 639000),
#   'name': 'insideunited',
#   'score': 0.3057961166097747,
#   'updatedAt': datetime.datetime(2021, 10, 12, 12, 5, 2, 639000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.2546771958898135,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615873f1248bfd23f2f84fab'),
#                                                  ObjectId('61587777248bfd7daaf84fcd'),
#                                                  ObjectId('615db2eadb45d073f69256a7'),
#                                                  ObjectId('615dbd75db45d041699256f1'),
#                                                  ObjectId('615f9f194f989b70704c283b'),
#                                                  ObjectId('615fa29d4f989b199f4c284d'),
#                                                  ObjectId('6160036fa52e729ce6170b61'),
#                                                  ObjectId('61612fe1a52e72c9ee17111f'),
#                                                  ObjectId('61613a6da52e7225c317112f'),
#                                                  ObjectId('6162a105a52e7258dd171553'),
#                                                  ObjectId('6162a80da52e72fce5171575'),
#                                                  ObjectId('6162f565a52e725f03171683'),
#                                                  ObjectId('616519d60be7441c36fc9a6d'),
#                                                  ObjectId('616520dd0be7449b56fc9a85')],
#                                     'contributionCount': 14}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.07142857142857142},
#   'createdAt': datetime.datetime(2021, 10, 2, 15, 0, 1, 389000),
#   'name': 'bitcoin',
#   'score': 0.01819122827784382,
#   'updatedAt': datetime.datetime(2021, 10, 12, 5, 45, 1, 653000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.03206530329476904,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61612fe1a52e7238a817110f'),
#                                                  ObjectId('61612fe1a52e7238a817110f')],
#                                     'contributionCount': 2}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.5},
#   'createdAt': datetime.datetime(2021, 10, 9, 6, 0, 1, 524000),
#   'name': 'bittorrent',
#   'score': 0.01603265164738452,
#   'updatedAt': datetime.datetime(2021, 10, 9, 6, 0, 1, 524000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.2886297348826684,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('6155b5fd8bcb97424b487272'),
#                                                  ObjectId('615a371d248bfdcbf8f85416'),
#                                                  ObjectId('615ccc0dae203585222da4d6'),
#                                                  ObjectId('615ec64cd17d164e3c55d235'),
#                                                  ObjectId('615ef07d16db7311fda6012b'),
#                                                  ObjectId('615f3dd54f989b36a14c264b'),
#                                                  ObjectId('61602ce5a52e7283d2170c9f'),
#                                                  ObjectId('6164216517d8253fc6079617'),
#                                                  ObjectId('616459a517d82580ea079785'),
#                                                  ObjectId('61655dcdcf52e6eb1ffca5d7')],
#                                     'contributionCount': 10}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.1},
#   'createdAt': datetime.datetime(2021, 9, 30, 13, 5, 1, 554000),
#   'name': 'transfers',
#   'score': 0.028862973488266844,
#   'updatedAt': datetime.datetime(2021, 10, 12, 10, 5, 1, 186000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 8.02462355478345e-05,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('6155cb158bcb97856e48732c')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 9, 30, 14, 35, 1, 307000),
#   'name': 'tomori',
#   'score': 8.02462355478345e-05,
#   'updatedAt': datetime.datetime(2021, 9, 30, 14, 35, 1, 307000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.00027190092949880295,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61581d3e248bfd3830f84c9d'),
#                                                  ObjectId('61581d47248bfd5498f84cbd')],
#                                     'contributionCount': 2}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.5},
#   'createdAt': datetime.datetime(2021, 10, 2, 8, 50, 6, 186000),
#   'name': 'nft',
#   'score': 0.00013595046474940148,
#   'updatedAt': datetime.datetime(2021, 10, 2, 8, 50, 15, 27000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.006019964160821003,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615e016edb45d0f8ff9258db')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 6, 20, 5, 2, 232000),
#   'name': 'gavi',
#   'score': 0.006019964160821003,
#   'updatedAt': datetime.datetime(2021, 10, 6, 20, 5, 2, 232000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.010421010694708221,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61598e5d248bfd6f9df85264'),
#                                                  ObjectId('6159e9c5248bfd73eef85354'),
#                                                  ObjectId('6159e9c5248bfd2cecf8535c'),
#                                                  ObjectId('615ae6e5ae2035705b2d9909'),
#                                                  ObjectId('615b2d37ae20355e622d9b49'),
#                                                  ObjectId('615ef07d16db7311fda6012b'),
#                                                  ObjectId('615f0c9d16db730bffa6020f'),
#                                                  ObjectId('615f0c9e16db7306c9a6021f')],
#                                     'contributionCount': 8}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.125},
#   'createdAt': datetime.datetime(2021, 10, 3, 11, 5, 1, 222000),
#   'name': 'watfordfc',
#   'score': 0.0013026263368385276,
#   'updatedAt': datetime.datetime(2021, 10, 7, 15, 5, 2, 382000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.006019964160821003,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615e016edb45d0f8ff9258db')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 6, 20, 5, 2, 232000),
#   'name': 'italyspain',
#   'score': 0.006019964160821003,
#   'updatedAt': datetime.datetime(2021, 10, 6, 20, 5, 2, 232000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.015141767006161164,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61581d40248bfd8955f84ca5'),
#                                                  ObjectId('61581d41248bfd9d4df84cad'),
#                                                  ObjectId('61581d44248bfd5e83f84cb5'),
#                                                  ObjectId('615fc28b4f989b35ec4c292e')],
#                                     'contributionCount': 4}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.25},
#   'createdAt': datetime.datetime(2021, 10, 2, 8, 50, 8, 443000),
#   'name': 'defi',
#   'score': 0.003785441751540291,
#   'updatedAt': datetime.datetime(2021, 10, 8, 4, 1, 15, 297000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.0003400727722958933,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61588a35248bfdc452f85017')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 2, 16, 35, 1, 700000),
#   'name': 'efc',
#   'score': 0.0003400727722958933,
#   'updatedAt': datetime.datetime(2021, 10, 2, 16, 35, 1, 700000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.23241802693703847,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615f28bc4f989b23b94c25a9'),
#                                                  ObjectId('615f2fc54f989b0f9d4c25d1'),
#                                                  ObjectId('615f2fc64f989b23f24c25d9'),
#                                                  ObjectId('6163a2d6a52e7202c517185b'),
#                                                  ObjectId('6163fad117d82508be079467'),
#                                                  ObjectId('6163ff8217d8259e6e079521'),
#                                                  ObjectId('6164f45517d8256241079b71')],
#                                     'contributionCount': 7}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.14285714285714285},
#   'createdAt': datetime.datetime(2021, 10, 7, 17, 5, 0, 904000),
#   'name': 'nufc',
#   'score': 0.03320257527671978,
#   'updatedAt': datetime.datetime(2021, 10, 12, 2, 35, 1, 362000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.04352939831646625,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615835d4248bfd3f95f84dc9'),
#                                                  ObjectId('615b7a8eae2035813c2d9d01'),
#                                                  ObjectId('615c3865ae20350b232da08a'),
#                                                  ObjectId('615c3865ae203542ac2da092'),
#                                                  ObjectId('6161bdada52e728b5b17131b'),
#                                                  ObjectId('6161c4b5a52e72dae0171355')],
#                                     'contributionCount': 6}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.16666666666666666},
#   'createdAt': datetime.datetime(2021, 10, 2, 10, 35, 0, 919000),
#   'name': 'realmadrid',
#   'score': 0.007254899719411042,
#   'updatedAt': datetime.datetime(2021, 10, 9, 16, 35, 1, 939000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.0005802486669506214,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61598e5d248bfd6f9df85264')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 3, 11, 5, 1, 222000),
#   'name': 'epl',
#   'score': 0.0005802486669506214,
#   'updatedAt': datetime.datetime(2021, 10, 3, 11, 5, 1, 222000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.0017640747756855974,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615babc5ae2035b9162d9de5')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 5, 1, 35, 1, 381000),
#   'name': 'dybala',
#   'score': 0.0017640747756855974,
#   'updatedAt': datetime.datetime(2021, 10, 5, 1, 35, 1, 381000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.051023158466683906,
#                  'contributions': [{'_id': ObjectId('614addffec903a9d987eb580'),
#                                     'contents': [ObjectId('6155bd068bcb9763174872ba'),
#                                                  ObjectId('615d97f6167e88362152244a'),
#                                                  ObjectId('615ef78516db73807ca60183'),
#                                                  ObjectId('616114eda52e724d9f171105'),
#                                                  ObjectId('6161eee5a52e724672171419'),
#                                                  ObjectId('6161fcf6a52e72aba1171445'),
#                                                  ObjectId('6162120da52e727339171479')],
#                                     'contributionCount': 7}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.14285714285714285},
#   'createdAt': datetime.datetime(2021, 9, 30, 13, 35, 2, 693000),
#   'name': 'threelions',
#   'score': 0.007289022638097701,
#   'updatedAt': datetime.datetime(2021, 10, 9, 22, 5, 1, 547000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.03625310193332887,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61616ba6a52e721e701711e5')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 9, 10, 15, 2, 220000),
#   'name': '684',
#   'score': 0.03625310193332887,
#   'updatedAt': datetime.datetime(2021, 10, 9, 10, 15, 2, 220000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.14058286453943555,
#                  'contributions': [{'_id': ObjectId('614addffec903a9d987eb580'),
#                                     'contents': [ObjectId('615ac3bfae203552b62d9805'),
#                                                  ObjectId('6163c5fda52e7265ff17189b'),
#                                                  ObjectId('6163fada17d825e87a079483'),
#                                                  ObjectId('6163ff8b17d825444207953d')],
#                                     'contributionCount': 4}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.25},
#   'createdAt': datetime.datetime(2021, 10, 4, 9, 5, 3, 152000),
#   'name': 'mondaymotivation',
#   'score': 0.03514571613485889,
#   'updatedAt': datetime.datetime(2021, 10, 11, 9, 10, 35, 337000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.13022468682419097,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61628161a52e724278171509'),
#                                                  ObjectId('6163d2e125d485dce6fc9879'),
#                                                  ObjectId('6163da4725d4856946fc98a1')],
#                                     'contributionCount': 3}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.3333333333333333},
#   'createdAt': datetime.datetime(2021, 10, 10, 6, 0, 1, 529000),
#   'name': 'binance',
#   'score': 0.04340822894139699,
#   'updatedAt': datetime.datetime(2021, 10, 11, 6, 31, 35, 240000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.08705821693596986,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('6161bdada52e728b5b17131b'),
#                                                  ObjectId('61631635a52e725c851716ff')],
#                                     'contributionCount': 2}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.5},
#   'createdAt': datetime.datetime(2021, 10, 9, 16, 5, 1, 120000),
#   'name': 'belgium',
#   'score': 0.04352910846798493,
#   'updatedAt': datetime.datetime(2021, 10, 10, 16, 35, 1, 109000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.00521056157063588,
#                  'contributions': [{'_id': ObjectId('614addffec903a9d987eb580'),
#                                     'contents': [ObjectId('615dbb1fdb45d03b139256d7')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 6, 15, 5, 3, 727000),
#   'name': 'wallpaperwednesday',
#   'score': 0.00521056157063588,
#   'updatedAt': datetime.datetime(2021, 10, 6, 15, 5, 3, 727000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.024785288642815678,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('6160b27da52e72941a171007')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 8, 21, 5, 1, 419000),
#   'name': 'haaland',
#   'score': 0.024785288642815678,
#   'updatedAt': datetime.datetime(2021, 10, 8, 21, 5, 1, 419000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.0011438628085704203,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615ad8d5ae2035478a2d987f'),
#                                                  ObjectId('615ad8d5ae2035389c2d9887')],
#                                     'contributionCount': 2}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.5},
#   'createdAt': datetime.datetime(2021, 10, 4, 10, 35, 1, 544000),
#   'name': 'real',
#   'score': 0.0005719314042852102,
#   'updatedAt': datetime.datetime(2021, 10, 4, 10, 35, 1, 581000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.0006591926503520076,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('6159cc79248bfd1f44f852f2')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 3, 15, 30, 1, 315000),
#   'name': '678',
#   'score': 0.0006591926503520076,
#   'updatedAt': datetime.datetime(2021, 10, 3, 15, 30, 1, 315000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.00014161322271521808,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('6156dfa58bcb97b14548793f')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 1, 10, 15, 1, 818000),
#   'name': '676',
#   'score': 0.00014161322271521808,
#   'updatedAt': datetime.datetime(2021, 10, 1, 10, 15, 1, 818000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.022187861106507608,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61607c96a52e723a93170ec9')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 8, 17, 15, 2, 176000),
#   'name': '63',
#   'score': 0.022187861106507608,
#   'updatedAt': datetime.datetime(2021, 10, 8, 17, 15, 2, 176000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.00039861782431039504,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('6158d78d248bfdedf4f85109')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 2, 22, 5, 1, 359000),
#   'name': 'ibrahimovic',
#   'score': 0.00039861782431039504,
#   'updatedAt': datetime.datetime(2021, 10, 2, 22, 5, 1, 359000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.00027194662794875453,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61581d3e248bfd3830f84c9d'),
#                                                  ObjectId('61581d40248bfd8955f84ca5'),
#                                                  ObjectId('61581d41248bfd9d4df84cad'),
#                                                  ObjectId('61581d44248bfd5e83f84cb5'),
#                                                  ObjectId('61581d47248bfd5498f84cbd'),
#                                                  ObjectId('61581d48248bfd5a19f84cc5'),
#                                                  ObjectId('61581d5b248bfd944ff84d2d')],
#                                     'contributionCount': 7}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.14285714285714285},
#   'createdAt': datetime.datetime(2021, 10, 2, 8, 50, 6, 186000),
#   'name': 'solana',
#   'score': 3.88495182783935e-05,
#   'updatedAt': datetime.datetime(2021, 10, 2, 8, 50, 35, 975000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.00027101903110192686,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('6157b295248bfdfd32f84a38'),
#                                                  ObjectId('61581bb2248bfd4184f84c15')],
#                                     'contributionCount': 2}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.5},
#   'createdAt': datetime.datetime(2021, 10, 2, 1, 15, 1, 422000),
#   'name': '5',
#   'score': 0.00013550951555096343,
#   'updatedAt': datetime.datetime(2021, 10, 2, 8, 43, 30, 77000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.010726362387724968,
#                  'contributions': [{'_id': ObjectId('614addffec903a9d987eb580'),
#                                     'contents': [ObjectId('615f1aae4f989b34394c2547')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 7, 16, 5, 2, 298000),
#   'name': 'navaratri',
#   'score': 0.010726362387724968,
#   'updatedAt': datetime.datetime(2021, 10, 7, 16, 5, 2, 298000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 7.080639663554624e-05,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61558e254f265120f13f7b39')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 9, 30, 10, 15, 1, 440000),
#   'name': '675',
#   'score': 7.080639663554624e-05,
#   'updatedAt': datetime.datetime(2021, 9, 30, 10, 15, 1, 440000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.00025888389433521386,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61580563248bfd7807f84b10')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 2, 7, 8, 19, 992000),
#   'name': 'btt',
#   'score': 0.00025888389433521386,
#   'updatedAt': datetime.datetime(2021, 10, 2, 7, 8, 19, 992000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.03206532361713649,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61612fe1a52e72da8f171117')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 9, 6, 0, 1, 603000),
#   'name': 'treemillions',
#   'score': 0.03206532361713649,
#   'updatedAt': datetime.datetime(2021, 10, 9, 6, 0, 1, 603000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.029474819846844403,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615bceedae203546fe2d9e45'),
#                                                  ObjectId('615ccc0dae20351f6b2da4ce'),
#                                                  ObjectId('6160a46da52e72ed2d170faf'),
#                                                  ObjectId('616106dda52e724c0f1710f5')],
#                                     'contributionCount': 4}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.25},
#   'createdAt': datetime.datetime(2021, 10, 5, 4, 5, 1, 124000),
#   'name': 'inter',
#   'score': 0.007368704961711101,
#   'updatedAt': datetime.datetime(2021, 10, 9, 3, 5, 1, 327000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.14056896583474593,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61632b4da52e721512171731'),
#                                                  ObjectId('61632b4da52e72b601171739'),
#                                                  ObjectId('61633255a52e726847171769'),
#                                                  ObjectId('61633255a52e7239de171771'),
#                                                  ObjectId('6163facc17d8253607079447'),
#                                                  ObjectId('6163facd17d825540507944f'),
#                                                  ObjectId('6163face17d825f050079457'),
#                                                  ObjectId('6163ff7d17d82576a4079501'),
#                                                  ObjectId('6163ff7e17d825029b079509'),
#                                                  ObjectId('6163ff7f17d8258e31079511')],
#                                     'contributionCount': 10}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.1},
#   'createdAt': datetime.datetime(2021, 10, 10, 18, 5, 1, 739000),
#   'name': 'thfc',
#   'score': 0.014056896583474594,
#   'updatedAt': datetime.datetime(2021, 10, 11, 9, 10, 23, 13000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.0018961530365339135,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615bceedae203546fe2d9e45')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 5, 4, 5, 1, 124000),
#   'name': 'af',
#   'score': 0.0018961530365339135,
#   'updatedAt': datetime.datetime(2021, 10, 5, 4, 5, 1, 124000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.29282940052365436,
#                  'contributions': [{'_id': ObjectId('614addffec903a9d987eb580'),
#                                     'contents': [ObjectId('6157239e248bfda510f846d9'),
#                                                  ObjectId('615731b0248bfd0488f84781'),
#                                                  ObjectId('61589f4e248bfd4046f85061'),
#                                                  ObjectId('6158de96248bfd550af85119'),
#                                                  ObjectId('616017cda52e72b271170be3'),
#                                                  ObjectId('616025dea52e728756170c6d'),
#                                                  ObjectId('6160500ea52e720bba170dab'),
#                                                  ObjectId('6160965ea52e72b972170f65'),
#                                                  ObjectId('61624345a52e7262e11714cd'),
#                                                  ObjectId('616564d5cf52e678cefca613')],
#                                     'contributionCount': 10}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.1},
#   'createdAt': datetime.datetime(2021, 10, 1, 15, 5, 2, 144000),
#   'name': 'pl',
#   'score': 0.02928294005236544,
#   'updatedAt': datetime.datetime(2021, 10, 12, 10, 35, 1, 803000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.018126527553911042,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61601a26a52e7228f0170bfd')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 8, 10, 15, 2, 59000),
#   'name': '683',
#   'score': 0.018126527553911042,
#   'updatedAt': datetime.datetime(2021, 10, 8, 10, 15, 2, 59000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.0031889518301073116,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61586e15248bfd458af84f83'),
#                                                  ObjectId('615ccc0dae203585222da4d6')],
#                                     'contributionCount': 2}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.5},
#   'createdAt': datetime.datetime(2021, 10, 2, 14, 35, 1, 624000),
#   'name': 'asroma',
#   'score': 0.0015944759150536558,
#   'updatedAt': datetime.datetime(2021, 10, 5, 22, 5, 1, 720000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.16198844254553207,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('6155a7ed8bcb9775614871d8'),
#                                                  ObjectId('6155aef68bcb97055e487220'),
#                                                  ObjectId('6155aef68bcb970c7b487228'),
#                                                  ObjectId('6156cf3d8bcb9777bd4878c5'),
#                                                  ObjectId('615746c4248bfd5652f8483a'),
#                                                  ObjectId('61580ef1248bfd4e21f84b43'),
#                                                  ObjectId('61580ef5248bfd0133f84b5b'),
#                                                  ObjectId('61584aed248bfd0116f84e9f'),
#                                                  ObjectId('61587c25248bfdfd13f84fd5'),
#                                                  ObjectId('6158d78c248bfd4270f85101'),
#                                                  ObjectId('615ee97516db738fc4a600eb'),
#                                                  ObjectId('61601ed5a52e72272b170c1d'),
#                                                  ObjectId('61601ed5a52e722f6b170c25'),
#                                                  ObjectId('61608f55a52e7259c5170f33'),
#                                                  ObjectId('6161a895a52e72c3f31712a3'),
#                                                  ObjectId('61631635a52e725c851716ff'),
#                                                  ObjectId('6164448d17d8250448079723')],
#                                     'contributionCount': 17}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.058823529411764705},
#   'createdAt': datetime.datetime(2021, 9, 30, 12, 5, 1, 924000),
#   'name': 'fcb',
#   'score': 0.009528731914443063,
#   'updatedAt': datetime.datetime(2021, 10, 11, 14, 5, 1, 556000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.14056896583474593,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61632b4da52e721512171731'),
#                                                  ObjectId('61632b4da52e72b601171739'),
#                                                  ObjectId('61633255a52e7239de171771'),
#                                                  ObjectId('6163facc17d8253607079447'),
#                                                  ObjectId('6163face17d825f050079457'),
#                                                  ObjectId('6163ff7d17d82576a4079501'),
#                                                  ObjectId('6163ff7f17d8258e31079511')],
#                                     'contributionCount': 7}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.14285714285714285},
#   'createdAt': datetime.datetime(2021, 10, 10, 18, 5, 1, 739000),
#   'name': 'spurs',
#   'score': 0.020081280833535133,
#   'updatedAt': datetime.datetime(2021, 10, 11, 9, 10, 23, 13000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.0013026533931215893,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615a371d248bfdcbf8f85416'),
#                                                  ObjectId('615b1820ae20356cca2d9aa7')],
#                                     'contributionCount': 2}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.5},
#   'createdAt': datetime.datetime(2021, 10, 3, 23, 5, 1, 104000),
#   'name': 'villarreal',
#   'score': 0.0006513266965607946,
#   'updatedAt': datetime.datetime(2021, 10, 4, 15, 5, 4, 971000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 7.684421069608669e-05,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('6155b5fd8bcb97424b487272')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 9, 30, 13, 5, 1, 554000),
#   'name': 'napoli',
#   'score': 7.684421069608669e-05,
#   'updatedAt': datetime.datetime(2021, 9, 30, 13, 5, 1, 554000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.07983309942626282,
#                  'contributions': [{'_id': ObjectId('614addffec903a9d987eb580'),
#                                     'contents': [ObjectId('6162a5b5a52e723df817156b'),
#                                                  ObjectId('6162ec05a52e72f657171651')],
#                                     'contributionCount': 2}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.5},
#   'createdAt': datetime.datetime(2021, 10, 10, 8, 35, 1, 247000),
#   'name': 'worldmentalhealthday',
#   'score': 0.03991654971313141,
#   'updatedAt': datetime.datetime(2021, 10, 10, 13, 35, 1, 675000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.0014621488960227806,
#                  'contributions': [{'_id': ObjectId('614addffec903a9d987eb580'),
#                                     'contents': [ObjectId('6155ee3e8bcb972ea6487430'),
#                                                  ObjectId('6156f265248bfd1686f8456d'),
#                                                  ObjectId('61570075248bfd42c8f845cf'),
#                                                  ObjectId('61570075248bfd0b35f845d9'),
#                                                  ObjectId('6157077d248bfd62acf8460b'),
#                                                  ObjectId('6157077d248bfd40c1f84615'),
#                                                  ObjectId('615731b0248bfd0488f84781'),
#                                                  ObjectId('6157860d248bfd2a45f849b2'),
#                                                  ObjectId('6157b03e248bfd12cdf84a2e'),
# ...
#                                                  ObjectId('6164b05d17d8251774079a05'),
#                                                  ObjectId('6164b76517d82555d5079a0d'),
#                                                  ObjectId('6164b76617d825ab5a079a15'),
#                                                  ObjectId('6164b76617d82585bc079a1d'),
#                                                  ObjectId('6164b76617d8258167079a25'),
#                                                  ObjectId('6164b76617d825392d079a2d'),
#                                                  ObjectId('6164be6d17d8254af1079a3f'),
#                                                  ObjectId('6164be6d17d825e478079a47'),
#                                                  ObjectId('6164c1f117d8253f4d079a4f'),
#                                                  ObjectId('6164c1f117d8250ac2079a57'),
#                                                  ObjectId('6164c1f117d8251147079a5f'),
#                                                  ObjectId('6164c57517d8250a1e079a67'),
#                                                  ObjectId('6164c57517d82580c0079a6f'),
#                                                  ObjectId('6164c57517d825107e079a77'),
#                                                  ObjectId('6164cc7c17d825be38079a7f'),
#                                                  ObjectId('6164cc7d17d8254417079a87'),
#                                                  ObjectId('6164cc7d17d825d9d8079a8f'),
#                                                  ObjectId('6164da8e17d8251d8b079a97'),
#                                                  ObjectId('6164de1117d825a689079aa7'),
#                                                  ObjectId('6164de1117d8253527079aaf'),
#                                                  ObjectId('6164df4217d8255ea0079ac1'),
#                                                  ObjectId('6164df4417d8254fa6079ac9'),
#                                                  ObjectId('6164df4617d825837d079ad1'),
#                                                  ObjectId('6164df4717d8256f3e079ad9'),
#                                                  ObjectId('6164df4817d825160c079ae1'),
#                                                  ObjectId('6164e19517d825fadc079ae9'),
#                                                  ObjectId('6164e19517d8256c89079af1'),
#                                                  ObjectId('6164f02217d8251bda079af9'),
#                                                  ObjectId('6164f02417d8257f0e079b01'),
#                                                  ObjectId('6164f02517d825013b079b09'),
#                                                  ObjectId('6164f02917d8251d56079b11'),
#                                                  ObjectId('6164f02e17d8255ab9079b19'),
#                                                  ObjectId('6164f11217d825fd15079b21'),
#                                                  ObjectId('6164f11417d8256c7a079b29'),
#                                                  ObjectId('6164f11617d825a6d9079b31'),
#                                                  ObjectId('6164f11c17d8252a25079b39'),
#                                                  ObjectId('6164f12017d825cb07079b41'),
#                                                  ObjectId('6164f3a617d82593ad079b49'),
#                                                  ObjectId('6164f3a917d8254987079b51'),
#                                                  ObjectId('6164f3aa17d825da14079b59'),
#                                                  ObjectId('6164f3b017d82532a0079b61'),
#                                                  ObjectId('6164f3b517d825fce9079b69'),
#                                                  ObjectId('6164f45a17d82581f0079b79'),
#                                                  ObjectId('6164f45c17d82510da079b81'),
#                                                  ObjectId('6164f45e17d8255569079b89'),
#                                                  ObjectId('6164f46317d825eaf2079b91'),
#                                                  ObjectId('6164f46717d8254518079b99'),
#                                                  ObjectId('6164f49717d8256337079ba1'),
#                                                  ObjectId('6164f49917d82548bd079ba9'),
#                                                  ObjectId('6164f49d17d8256aa0079bb1'),
#                                                  ObjectId('6164f4a017d825386f079bb9'),
#                                                  ObjectId('6164f6ad17d8251694079bc9'),
#                                                  ObjectId('6164f6ad17d8258469079bd1'),
#                                                  ObjectId('6164fdb60be7440fddfc9a03'),
#                                                  ObjectId('6164fdb60be7446f2dfc9a0b'),
#                                                  ObjectId('61650bc60be7441257fc9a1d'),
#                                                  ObjectId('61650bc60be7446872fc9a25'),
#                                                  ObjectId('61650bc60be7444b1cfc9a2d'),
#                                                  ObjectId('61650bc60be7443697fc9a35'),
#                                                  ObjectId('61650f4a0be74404f2fc9a3d'),
#                                                  ObjectId('616516520be74429c0fc9a45'),
#                                                  ObjectId('616516520be7448375fc9a4d'),
#                                                  ObjectId('616519d50be7442fcdfc9a55'),
#                                                  ObjectId('616519d50be744f2a7fc9a5d'),
#                                                  ObjectId('616519d60be7441af7fc9a65'),
#                                                  ObjectId('61651d590be7448628fc9a75'),
#                                                  ObjectId('616520dd0be74406befc9a7d'),
#                                                  ObjectId('616524610be744a467fc9a8d'),
#                                                  ObjectId('616527e50be7447d70fc9a95'),
#                                                  ObjectId('61652b6a614a6a6d1f8d8aa1'),
#                                                  ObjectId('61653272af656fc9d59c8efb'),
#                                                  ObjectId('61653272af656f68b29c8f03'),
#                                                  ObjectId('61653272af656f050c9c8f0b'),
#                                                  ObjectId('61653cfdaf656fded99c8f13'),
#                                                  ObjectId('61653cfdaf656f244a9c8f1b'),
#                                                  ObjectId('61654081af656f71259c8f23'),
#                                                  ObjectId('61654405af656f29479c8f2b'),
#                                                  ObjectId('61654405af656f47469c8f33'),
#                                                  ObjectId('61654405af656f335a9c8f3b'),
#                                                  ObjectId('6165478aaf656f704a9c8f43'),
#                                                  ObjectId('61654b0daf656fb2fd9c8f4d'),
#                                                  ObjectId('61654b0daf656f1ae89c8f57'),
#                                                  ObjectId('61654e90af656fa6799c8f61'),
#                                                  ObjectId('61654e91af656f10b69c8f6b'),
#                                                  ObjectId('61654e91af656f5daf9c8f75'),
#                                                  ObjectId('61654e91af656fbf579c8f7f'),
#                                                  ObjectId('61654e91af656f80e39c8f89'),
#                                                  ObjectId('61655215af656f1a4c9c8f93'),
#                                                  ObjectId('61655215af656f66c29c8f9d'),
#                                                  ObjectId('61655215af656f013e9c8fa7'),
#                                                  ObjectId('61655215af656f01db9c8fb1'),
#                                                  ObjectId('61655215af656fda509c8fbb'),
#                                                  ObjectId('61655599af656fe7ce9c8fc8'),
#                                                  ObjectId('6165591daf656f48259c8fe0'),
#                                                  ObjectId('6165591eaf656f60059c8fea'),
#                                                  ObjectId('6165591eaf656f71779c8ff4'),
#                                                  ObjectId('61655ca2cf52e67ec7fca5c3'),
#                                                  ObjectId('61655ca3cf52e64ca0fca5cd'),
#                                                  ObjectId('61656026cf52e60a02fca5e1'),
#                                                  ObjectId('61656026cf52e66de7fca5eb'),
#                                                  ObjectId('61656026cf52e63becfca5ff'),
#                                                  ObjectId('616563aacf52e626e2fca609'),
#                                                  ObjectId('6165672fcf52e605c2fca61e'),
#                                                  ObjectId('6165672fcf52e67c7efca628'),
#                                                  ObjectId('6165672fcf52e6bf8cfca632'),
#                                                  ObjectId('61656730cf52e69527fca63c'),
#                                                  ObjectId('61656730cf52e6e2e2fca646'),
#                                                  ObjectId('61656e3581952ae1d92c3333'),
#                                                  ObjectId('61656e3681952aa8282c333d'),
#                                                  ObjectId('61656e3681952a77fd2c3347'),
#                                                  ObjectId('616571ba81952a04532c3351'),
#                                                  ObjectId('6165753d81952a2bbc2c3365'),
#                                                  ObjectId('6165753d81952a78ca2c336f'),
#                                                  ObjectId('616578c181952afdef2c3379'),
#                                                  ObjectId('616578c281952a39982c3383'),
#                                                  ObjectId('616578c281952a21c32c338d'),
#                                                  ObjectId('616578c281952a20ea2c3397'),
#                                                  ObjectId('616578c281952abd132c33a1'),
#                                                  ObjectId('616578c281952aa8452c33ab'),
#                                                  ObjectId('616578c281952ae34f2c33b5'),
#                                                  ObjectId('61657c4581952a39852c33ca'),
#                                                  ObjectId('61657c4581952a59d82c33d4'),
#                                                  ObjectId('61657fc981952ae80d2c33de'),
#                                                  ObjectId('6165834d81952a91102c33e8'),
#                                                  ObjectId('6165834d81952ab3b12c33f2'),
#                                                  ObjectId('6165834d81952a74852c33fc'),
#                                                  ObjectId('6165834d81952a05c52c3406'),
#                                                  ObjectId('616586d181952a7d252c3410'),
#                                                  ObjectId('616586d281952a9f882c341a'),
#                                                  ObjectId('61658a5581952a59912c342f'),
#                                                  ObjectId('61658a5581952a5ff92c3439'),
#                                                  ObjectId('61658a5581952a98da2c3443'),
#                                                  ObjectId('61658a5681952a44982c344d'),
#                                                  ObjectId('61658a5681952ad7872c3457'),
#                                                  ObjectId('61658a5681952ad24f2c3461'),
#                                                  ObjectId('61658ad481952afb012c346b'),
#                                                  ObjectId('61658ad881952aa5662c3475'),
#                                                  ObjectId('61658adc81952a41ab2c347f'),
#                                                  ObjectId('61658ae081952a66c12c3489'),
#                                                  ObjectId('61658ae481952a31742c3493'),
#                                                  ObjectId('6165915d81952aae392c349d'),
#                                                  ObjectId('6165915d81952a500a2c34a7'),
#                                                  ObjectId('6165915d81952a53fc2c34b1'),
#                                                  ObjectId('616594e181952a57d02c34bb'),
#                                                  ObjectId('6165986481952abf842c34c5'),
#                                                  ObjectId('6165986581952a45822c34cf'),
#                                                  ObjectId('6165986581952a269e2c34d9'),
#                                                  ObjectId('6165986581952a703d2c34e3'),
#                                                  ObjectId('6165986581952aca542c34ed'),
#                                                  ObjectId('6165986581952a7c9b2c34f7'),
#                                                  ObjectId('61659bea81952a38442c3501')],
#                                     'contributionCount': 2109},
#                                    {'_id': ObjectId('614988493e62699352abc8eb'),
#                                     'contents': [ObjectId('615d19b1ae2035257b2da5da'),
#                                                  ObjectId('615d2400ae2035c7302da602')],
#                                     'contributionCount': 2},
#                                    {'_id': ObjectId('6151abf6809e787ef7568728'),
#                                     'contents': [ObjectId('615585824f2651a3c73f7afb'),
#                                                  ObjectId('6156e707248bfd17a9f8450b'),
#                                                  ObjectId('615dab47342a22288b3d9ca6')],
#                                     'contributionCount': 3},
#                                    {'_id': ObjectId('614addffec903a9d987eb580'),
#                                     'contents': [ObjectId('615b424dae2035cd0e2d9bcb'),
#                                                  ObjectId('61620b06a52e72d0c0171467')],
#                                     'contributionCount': 2}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.002360717658168083},
#   'createdAt': datetime.datetime(2021, 9, 30, 5, 15, 1, 915000),
#   'name': '',
#   'score': 0.0007740804720138825,
#   'updatedAt': datetime.datetime(2021, 10, 12, 14, 30, 2, 79000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.1907922244995739,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('6164943d17d825198e07996b')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 11, 19, 45, 1, 589000),
#   'name': '64',
#   'score': 0.1907922244995739,
#   'updatedAt': datetime.datetime(2021, 10, 11, 19, 45, 1, 589000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.23256331395703436,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('6163638da52e72a44f171809'),
#                                                  ObjectId('6163facb17d825d46807943f'),
#                                                  ObjectId('6163ff7b17d8250ec90794f9'),
#                                                  ObjectId('6164f4a317d82508b7079bc1')],
#                                     'contributionCount': 4}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.25},
#   'createdAt': datetime.datetime(2021, 10, 10, 22, 5, 1, 778000),
#   'name': 'writingthefutureoffootball',
#   'score': 0.05814082848925859,
#   'updatedAt': datetime.datetime(2021, 10, 12, 2, 36, 19, 257000)}]
