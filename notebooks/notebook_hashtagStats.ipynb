# %% [markdown]
# ########################################################################################

# %% [markdown]
# ## Upsert hashtagStats

# %% [markdown]
# ########################################################################################

# %% [markdown]
# ## (optional) libraries in trigger function

# %%
import pymongo # connect to MongoDB
from pymongo import MongoClient
from IPython.display import clear_output # clear output everytime running
from pprint import pprint

# %% [markdown]
# ## mandatory libraries in trigger function

# %%
import json
import sys
# from mongo_client import mongo_client
from bson.objectid import ObjectId
from bson import regex
from datetime import datetime, timedelta
import re
import math

# %%
# connect to MongoDB
## define connection URI as role; analytics-admin
connectionUri = 'mongodb+srv://analytics-admin:pnYT55BGWwHePK1M@dev-cluster.fg2e5.mongodb.net/myFirstDatabase?retryWrites=true&w=majority'

## assign client
client = pymongo.MongoClient(connectionUri)

## assign databases
appDb = client['app-db']
analyticsDb = client['analytics-db']

## assign collections
### source collections
contents = appDb['contents']

### destination collections
userStats = analyticsDb['userStats']
hashtagStats = analyticsDb['hashtagStats']

# %% [markdown]
# ########################################################################################

# %% [markdown]
# ########################################################################################

# %% [markdown]
# ## Hashtag parsing

# %% [markdown]
# ### note!!!: Be careful! running this cell cause collection changes

# %% [markdown]
# ### below cell just for filtering in testing

# %%
# define RegEx
namepattern = regex.Regex.from_native(re.compile(r"(?<=#)\w+"))
namepattern.flags ^= re.UNICODE

tagpattern = regex.Regex.from_native(re.compile(r"#\w+"))
tagpattern.flags ^= re.UNICODE

# %%
# define RegEx
pattern = regex.Regex.from_native(re.compile(r"(?<=#)\w+"))
pattern.flags ^= re.UNICODE

# define content parameters
contentDateThreshold = 14
likedWeight = 1
commentedWeight = 1
recastedWeight = 1
quotedWeight = 1
halfLifeHours = 24

# %%
# define cursor
cursor = [
    {
        # filter contents for newer than specific age
        '$match': {
            'createdAt': {
                '$gte': (datetime.utcnow() - timedelta(days=contentDateThreshold)) 
                }
        }
#     }, {
#             # !!! TESTING filter
#         '$match': {
#             'payload.message': {
#                     '$regex': tagpattern
#                 }
#         }
    }, {
        # extract hashtag => array
        '$addFields': {
            'hashtags': {
                '$regexFindAll': {
                    'input': '$payload.message', 
                    'regex': pattern
                }
            }
        }
    }, {
        # deconstruct hashtags array => hashtag object
        '$unwind': {
            'path': '$hashtags', 
            'preserveNullAndEmptyArrays': True
        }
    }, {
        # extract hashtag object => field
        '$addFields': {
        'name': {
            '$toLower': '$hashtags.match'
            }
        }
    }, {
        # filter non-hashtag contents out
        '$match': {
            'name': {
              '$ne': ''
          }
        }
    }, {
        # summarize by user (not account)
        # collect contentId as array
        '$group': {
            '_id': {
                'name': '$name',
                'authorId': '$author.id'
            }, 
            'contributionCount': {
                '$count': {}
            }, 
            'createdAt': {
                '$min': '$createdAt'
            }, 
            'updatedAt': {
                '$max': '$updatedAt'
            },
            'contents': {
                '$push': "$_id"
            },
            # ! follow app-db.hashtags schema
            '__v': {
                '$max': '$__v'
            },
            'likedCount': {
                '$sum': '$engagements.like.count'
            },
            'commentedCount': {
                '$sum': '$engagements.comment.count'
            },
            'recastedCount': {
                '$sum': '$engagements.recast.recast'
            },
            'quotedCount': {
                '$sum': '$engagements.quote.recast'
            }
        }
    }, {
        # summarize by hashtag
        '$group': {
            '_id': '$_id.name', 
            'hashtagCount': {
                '$sum': '$contributionCount'
            }, 
            'contributorCount': {'$count': {}},
            'createdAt': {
                '$min': '$createdAt'
            }, 
            'updatedAt': {
                '$max': '$updatedAt'
            },
            # ! follow app-db.hashtags schema
            '__v': {
                '$max': '$__v'
            },
            'contributions': {
                '$push': {
                    '_id': '$_id.authorId', 
                    'contributionCount': '$contributionCount', 
                    'contents': "$contents",
                }
            },
            'likedCount': {
                '$sum': '$likedCount'
            },
            'commentedCount': {
                '$sum': '$commentedCount'
            },
            'recastedCount': {
                '$sum': '$recastedCount'
            },
            'quotedCount': {
                '$sum': '$quotedCount'
            }
        }    
    }, {
        # setting output format
        '$project': {
            '_id': 0,  
            'name': '$_id',
            '__v': '$__v',
            'createdAt': 1, 
            'updatedAt': 1, 
            'aggregator.contributions': '$contributions',
            # calculate fraction of hashtag diversity
            ## equation: hastagDiversityScore = n_{user|hashtag}/n_{content|hashtag}
            'aggregator.hastagDiversityScore': {
                '$divide': [
                    '$contributorCount', '$hashtagCount'
                ]
            },
            # calculate linear combination of engagements 
            ## equation: engagementScore = {\sigma}_{k}({\beta}_{k}*x_{k})
            'aggregator.engagementScore': {
                '$sum': [
                    {
                        '$multiply': [
                            '$commentedCount', commentedWeight
                        ]
                    }, {
                        '$multiply': [
                            '$recastedCount', recastedWeight
                        ]
                    }, {
                        '$multiply': [
                            '$quotedCount', quotedWeight
                        ]
                    }, {
                        '$multiply': [
                            '$quotedCount', quotedWeight
                        ]
                    }
                ]
            },
            # calculate decay from last update time
            ## equation: ageScore = e^(-{\lambda}*t)
            'aggregator.ageScore': {
                '$exp': {
                    '$multiply': [
                        {
                            '$multiply': [
                                {
                                    # calculate age from last update time
                                    '$divide': [
                                        {
                                            '$subtract': [datetime.utcnow(), "$updatedAt"]
                                        }, 60*60*1000
                                    ]
                                }, {
                                    # define lambda value
                                    '$divide': [{'$ln': 2}, halfLifeHours]
                                }
                            ]
                        }, -1
                    ]
                }
            }            
        }
    }, {
        # summarize all scores
        ## equation: score = ageScore*(engagementScore + 1)*(hastagDiversityScore)
        '$addFields': {
            'score': {
                '$multiply': [
                    '$aggregator.hastagDiversityScore',
                    # add 1 as bias
                    {'$add': ['$aggregator.engagementScore', 1]},
                    '$aggregator.ageScore'
                ]
            }
        }   
#     }, {
#         # upsert to 'hashtagStats' collection
#         '$merge': {
#             'into': {
#                 'db': 'analytics-db', 
#                 'coll': 'hashtagStats'
#             }, 
#             'on': '_id', 
#             'whenMatched': 'replace', 
#             'whenNotMatched': 'insert'
#         }
    }
]

# %%
# clear the output
clear_output()

# print output
pprint(list(contents.aggregate(cursor)))
# Out:
# [{'__v': 0,
#   'aggregator': {'ageScore': 0.06951420964228329,
#                  'contributions': [{'_id': ObjectId('614addffec903a9d987eb580'),
#                                     'contents': [ObjectId('615ac3bfae203552b62d9805'),
#                                                  ObjectId('6163c5fda52e7265ff17189b'),
#                                                  ObjectId('6163fada17d825e87a079483'),
#                                                  ObjectId('6163ff8b17d825444207953d')],
#                                     'contributionCount': 4}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.25},
#   'createdAt': datetime.datetime(2021, 10, 4, 9, 5, 3, 152000),
#   'name': 'mondaymotivation',
#   'score': 0.017378552410570822,
#   'updatedAt': datetime.datetime(2021, 10, 11, 9, 10, 35, 337000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61616ba6a52e721e701711e5')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 9, 10, 15, 2, 220000),
#   'name': '684',
#   'score': 0.6620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.025229493977692904,
#                  'contributions': [{'_id': ObjectId('614addffec903a9d987eb580'),
#                                     'contents': [ObjectId('615d97f6167e88362152244a'),
#                                                  ObjectId('615ef78516db73807ca60183'),
#                                                  ObjectId('616114eda52e724d9f171105'),
#                                                  ObjectId('6161eee5a52e724672171419'),
#                                                  ObjectId('6161fcf6a52e72aba1171445'),
#                                                  ObjectId('6162120da52e727339171479')],
#                                     'contributionCount': 6}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.16666666666666666},
#   'createdAt': datetime.datetime(2021, 10, 6, 12, 35, 2, 953000),
#   'name': 'threelions',
#   'score': 0.004204915662948817,
#   'updatedAt': datetime.datetime(2021, 10, 9, 22, 5, 1, 547000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615babc5ae2035b9162d9de5')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 5, 1, 35, 1, 381000),
#   'name': 'dybala',
#   'score': 0.6620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615835d4248bfd3f95f84dc9'),
#                                                  ObjectId('615b7a8eae2035813c2d9d01'),
#                                                  ObjectId('615c3865ae20350b232da08a'),
#                                                  ObjectId('615c3865ae203542ac2da092'),
#                                                  ObjectId('6161bdada52e728b5b17131b'),
#                                                  ObjectId('6161c4b5a52e72dae0171355'),
#                                                  ObjectId('6168401669973eec2a167ec7')],
#                                     'contributionCount': 7}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.14285714285714285},
#   'createdAt': datetime.datetime(2021, 10, 2, 10, 35, 0, 919000),
#   'name': 'realmadrid',
#   'score': 0.09457202585953457,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61598e5d248bfd6f9df85264')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 3, 11, 5, 1, 222000),
#   'name': 'epl',
#   'score': 0.6620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615f28bc4f989b23b94c25a9'),
#                                                  ObjectId('615f2fc54f989b0f9d4c25d1'),
#                                                  ObjectId('615f2fc64f989b23f24c25d9'),
#                                                  ObjectId('6163a2d6a52e7202c517185b'),
#                                                  ObjectId('6163fad117d82508be079467'),
#                                                  ObjectId('6163ff8217d8259e6e079521'),
#                                                  ObjectId('6164f45517d8256241079b71'),
#                                                  ObjectId('616823f569973e7ef9167d72')],
#                                     'contributionCount': 8}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.125},
#   'createdAt': datetime.datetime(2021, 10, 7, 17, 5, 0, 904000),
#   'name': 'nufc',
#   'score': 0.08275052262709276,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61588a35248bfdc452f85017')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 2, 16, 35, 1, 700000),
#   'name': 'efc',
#   'score': 0.6620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615e016edb45d0f8ff9258db')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 6, 20, 5, 2, 232000),
#   'name': 'italyspain',
#   'score': 0.6620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61598e5d248bfd6f9df85264'),
#                                                  ObjectId('6159e9c5248bfd73eef85354'),
#                                                  ObjectId('6159e9c5248bfd2cecf8535c'),
#                                                  ObjectId('615ae6e5ae2035705b2d9909'),
#                                                  ObjectId('615b2d37ae20355e622d9b49'),
#                                                  ObjectId('615ef07d16db7311fda6012b'),
#                                                  ObjectId('615f0c9d16db730bffa6020f'),
#                                                  ObjectId('615f0c9e16db7306c9a6021f')],
#                                     'contributionCount': 8}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.125},
#   'createdAt': datetime.datetime(2021, 10, 3, 11, 5, 1, 222000),
#   'name': 'watfordfc',
#   'score': 0.08275052262709276,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61581d40248bfd8955f84ca5'),
#                                                  ObjectId('61581d41248bfd9d4df84cad'),
#                                                  ObjectId('61581d44248bfd5e83f84cb5'),
#                                                  ObjectId('615fc28b4f989b35ec4c292e')],
#                                     'contributionCount': 4}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.25},
#   'createdAt': datetime.datetime(2021, 10, 2, 8, 50, 8, 443000),
#   'name': 'defi',
#   'score': 0.16550104525418552,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61581d3e248bfd3830f84c9d'),
#                                                  ObjectId('61581d47248bfd5498f84cbd')],
#                                     'contributionCount': 2}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.5},
#   'createdAt': datetime.datetime(2021, 10, 2, 8, 50, 6, 186000),
#   'name': 'nft',
#   'score': 0.33100209050837104,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615e016edb45d0f8ff9258db')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 6, 20, 5, 2, 232000),
#   'name': 'gavi',
#   'score': 0.6620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6595705501275686,
#                  'contributions': [{'_id': ObjectId('614addffec903a9d987eb580'),
#                                     'contents': [ObjectId('6168471e6ee6fb509b9560c4')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 14, 15, 5, 2, 452000),
#   'name': 'kopatrophy',
#   'score': 0.6595705501275686,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 5, 2, 452000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615a371d248bfdcbf8f85416'),
#                                                  ObjectId('615ccc0dae203585222da4d6'),
#                                                  ObjectId('615ec64cd17d164e3c55d235'),
#                                                  ObjectId('615ef07d16db7311fda6012b'),
#                                                  ObjectId('615f3dd54f989b36a14c264b'),
#                                                  ObjectId('61602ce5a52e7283d2170c9f'),
#                                                  ObjectId('6164216517d8253fc6079617'),
#                                                  ObjectId('616459a517d82580ea079785'),
#                                                  ObjectId('61655dcdcf52e6eb1ffca5d7'),
#                                                  ObjectId('61680edef48bc251f314a5a2')],
#                                     'contributionCount': 10}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.1},
#   'createdAt': datetime.datetime(2021, 10, 3, 23, 5, 1, 104000),
#   'name': 'transfers',
#   'score': 0.06620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615873f1248bfd23f2f84fab'),
#                                                  ObjectId('61587777248bfd7daaf84fcd'),
#                                                  ObjectId('615db2eadb45d073f69256a7'),
#                                                  ObjectId('615dbd75db45d041699256f1'),
#                                                  ObjectId('615f9f194f989b70704c283b'),
#                                                  ObjectId('615fa29d4f989b199f4c284d'),
#                                                  ObjectId('6160036fa52e729ce6170b61'),
#                                                  ObjectId('61612fe1a52e72c9ee17111f'),
#                                                  ObjectId('61613a6da52e7225c317112f'),
#                                                  ObjectId('6162a105a52e7258dd171553'),
#                                                  ObjectId('6162a80da52e72fce5171575'),
#                                                  ObjectId('6162f565a52e725f03171683'),
#                                                  ObjectId('616519d60be7441c36fc9a6d'),
#                                                  ObjectId('616520dd0be7449b56fc9a85')],
#                                     'contributionCount': 14}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.07142857142857142},
#   'createdAt': datetime.datetime(2021, 10, 2, 15, 0, 1, 389000),
#   'name': 'bitcoin',
#   'score': 0.047286012929767286,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.15120744215483697,
#                  'contributions': [{'_id': ObjectId('614addffec903a9d987eb580'),
#                                     'contents': [ObjectId('616579ee81952a3d5f2c33bf')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 12, 12, 5, 2, 639000),
#   'name': 'insideunited',
#   'score': 0.15120744215483697,
#   'updatedAt': datetime.datetime(2021, 10, 12, 12, 5, 2, 639000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61612fe1a52e7238a817110f'),
#                                                  ObjectId('61612fe1a52e7238a817110f')],
#                                     'contributionCount': 2}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.5},
#   'createdAt': datetime.datetime(2021, 10, 9, 6, 0, 1, 524000),
#   'name': 'bittorrent',
#   'score': 0.33100209050837104,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.5876154462021451,
#                  'contributions': [{'_id': ObjectId('614addffec903a9d987eb580'),
#                                     'contents': [ObjectId('6156cf3e8bcb970b1f4878cd'),
#                                                  ObjectId('6157da6d248bfd6e11f84a7a'),
#                                                  ObjectId('615a614d248bfd282ef85440'),
#                                                  ObjectId('615d6dc6ae2035f4082da63f'),
#                                                  ObjectId('615e7ffddb45d0ef3f925ad9'),
#                                                  ObjectId('615fc36e4f989b78e14c293e'),
#                                                  ObjectId('6161cbbea52e720afd17138d'),
#                                                  ObjectId('6162666da52e7258b21714ef'),
#                                                  ObjectId('616491e617d8252b20079959'),
#                                                  ObjectId('61659d1681952a329b2c350b'),
#                                                  ObjectId('61680edff48bc27dc614a5c0')],
#                                     'contributionCount': 11}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.09090909090909091},
#   'createdAt': datetime.datetime(2021, 10, 1, 9, 5, 2, 125000),
#   'name': 'goaloftheday',
#   'score': 0.05341958601837683,
#   'updatedAt': datetime.datetime(2021, 10, 14, 11, 5, 3, 489000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615c699dae20357d3e2da206')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 5, 15, 5, 1, 412000),
#   'name': 'ultraweave',
#   'score': 0.6620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615f0c9e16db7318c0a60217')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 7, 15, 5, 2, 318000),
#   'name': 'espa',
#   'score': 0.6620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615c699dae20357d3e2da206')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 5, 15, 5, 1, 412000),
#   'name': 'italia',
#   'score': 0.6620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61584aed248bfd0116f84e9f')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 2, 12, 5, 1, 741000),
#   'name': 'koeman',
#   'score': 0.6620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('6163dcdc25d4854011fc98d3'),
#                                                  ObjectId('6163de6225d485c4b9fc990b')],
#                                     'contributionCount': 2}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.5},
#   'createdAt': datetime.datetime(2021, 10, 11, 6, 42, 36, 288000),
#   'name': 'be_active_be_earning',
#   'score': 0.33100209050837104,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('6161cbbea52e727fcb171385'),
#                                                  ObjectId('61680edef48bc251f314a5a2')],
#                                     'contributionCount': 2}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.5},
#   'createdAt': datetime.datetime(2021, 10, 9, 17, 5, 2, 60000),
#   'name': 'acmilan',
#   'score': 0.33100209050837104,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615bf7f1ae2035646b2d9eef')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 5, 7, 0, 1, 280000),
#   'name': 'huobiturns8',
#   'score': 0.6620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61680eddf48bc2079014a58e'),
#                                                  ObjectId('616823f569973eca6f167d68')],
#                                     'contributionCount': 2}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.5},
#   'createdAt': datetime.datetime(2021, 10, 14, 11, 5, 1, 896000),
#   'name': 'pedri',
#   'score': 0.33100209050837104,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61581d3e248bfd3830f84c9d'),
#                                                  ObjectId('61581d47248bfd5498f84cbd')],
#                                     'contributionCount': 2}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.5},
#   'createdAt': datetime.datetime(2021, 10, 2, 8, 50, 6, 186000),
#   'name': 'nftcollector',
#   'score': 0.33100209050837104,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61581d44248bfd5e83f84cb5')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 2, 8, 50, 12, 98000),
#   'name': 'sol',
#   'score': 0.6620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61583125248bfdbd4cf84dc1')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 2, 10, 15, 1, 224000),
#   'name': '677',
#   'score': 0.6620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6048279538734329,
#                  'contributions': [{'_id': ObjectId('614addffec903a9d987eb580'),
#                                     'contents': [ObjectId('61608f56a52e72762d170f3b'),
#                                                  ObjectId('61681cee69973eff0c167d2b')],
#                                     'contributionCount': 2}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.5},
#   'createdAt': datetime.datetime(2021, 10, 8, 18, 35, 2, 86000),
#   'name': 'ballondor',
#   'score': 0.30241397693671646,
#   'updatedAt': datetime.datetime(2021, 10, 14, 12, 5, 2, 265000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615f4be54f989b143f4c26c5')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 7, 19, 35, 1, 741000),
#   'name': 'deadlineday',
#   'score': 0.6620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6501159515460703,
#                  'contributions': [{'_id': ObjectId('614addffec903a9d987eb580'),
#                                     'contents': [ObjectId('6168401669973e381e167ed1')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 14, 14, 35, 2, 746000),
#   'name': 'conticup',
#   'score': 0.6501159515460703,
#   'updatedAt': datetime.datetime(2021, 10, 14, 14, 35, 2, 746000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615c699dae20351eaf2da1fe')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 5, 15, 5, 1, 361000),
#   'name': 'arsenal',
#   'score': 0.6620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615fc28b4f989b35ec4c292e'),
#                                                  ObjectId('615fc28b4f989b35ec4c292e')],
#                                     'contributionCount': 2}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.5},
#   'createdAt': datetime.datetime(2021, 10, 8, 4, 1, 15, 297000),
#   'name': 'web3',
#   'score': 0.33100209050837104,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615c25a5ae20356cfd2da008')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 5, 10, 15, 1, 435000),
#   'name': '680',
#   'score': 0.6620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('6162585da52e72626c1714df')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 10, 3, 5, 1, 423000),
#   'name': 'mbap',
#   'score': 0.6620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615ad8d5ae2035074d2d988f'),
#                                                  ObjectId('615b2d37ae203546822d9b51'),
#                                                  ObjectId('615b7a8dae2035647c2d9cf9'),
#                                                  ObjectId('615b7a8eae2035813c2d9d01'),
#                                                  ObjectId('615b8195ae20356d0b2d9d21'),
#                                                  ObjectId('615bd5f5ae20354c922d9e55'),
#                                                  ObjectId('615bd5f5ae20353e402d9e5d'),
#                                                  ObjectId('615c3865ae20350b232da08a'),
#                                                  ObjectId('615c3865ae203542ac2da092'),
#                                                  ObjectId('615c699dae203512f42da20e'),
#                                                  ObjectId('6161cbbda52e7261d217137d'),
#                                                  ObjectId('61680edef48bc2f5f414a5ac')],
#                                     'contributionCount': 12}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.08333333333333333},
#   'createdAt': datetime.datetime(2021, 10, 4, 10, 35, 1, 617000),
#   'name': 'mbapp',
#   'score': 0.0551670150847285,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.0007229908511207577,
#                  'contributions': [{'_id': ObjectId('614addffec903a9d987eb580'),
#                                     'contents': [ObjectId('6156f265248bfd1686f8456d'),
#                                                  ObjectId('61570075248bfd42c8f845cf'),
#                                                  ObjectId('61570075248bfd0b35f845d9'),
#                                                  ObjectId('6157077d248bfd62acf8460b'),
#                                                  ObjectId('6157077d248bfd40c1f84615'),
#                                                  ObjectId('615731b0248bfd0488f84781'),
#                                                  ObjectId('6157860d248bfd2a45f849b2'),
#                                                  ObjectId('6157b03e248bfd12cdf84a2e'),
#                                                  ObjectId('6157da6d248bfd6e11f84a7a'),
#                                                  ObjectId('6157ef86248bfd54b5f84a94'),
#                                                  ObjectId('6157fd96248bfd3068f84a9e'),
#                                                  ObjectId('615819b5248bfd1c6df84b73'),
#                                                  ObjectId('61582ece248bfd2ee5f84daf'),
#                                                  ObjectId('615835d6248bfda294f84dd9'),
#                                                  ObjectId('615835d6248bfda322f84de3'),
#                                                  ObjectId('615835d6248bfd17b5f84ded'),
#                                                  ObjectId('61583cdd248bfd78d8f84e37'),
#                                                  ObjectId('61583cdd248bfd4ec5f84e41'),
#                                                  ObjectId('61583cdd248bfdcdf3f84e4b'),
#                                                  ObjectId('615843e6248bfdb271f84e65'),
#                                                  ObjectId('615843e6248bfdd2b9f84e6f'),
#                                                  ObjectId('615843e6248bfd0672f84e83'),
#                                                  ObjectId('615843e7248bfd84eef84e8d'),
#                                                  ObjectId('61584aee248bfd7633f84ea7'),
#                                                  ObjectId('61584aef248bfd7b4ef84eb1'),
#                                                  ObjectId('61584aef248bfdfe6ef84ebb'),
#                                                  ObjectId('615851f6248bfd7b11f84ec5'),
#                                                  ObjectId('615851f6248bfd4dbaf84ecf'),
#                                                  ObjectId('615851f6248bfd3346f84ed9'),
#                                                  ObjectId('615851f7248bfdd78cf84ee3'),
#                                                  ObjectId('615851f7248bfd3370f84eed'),
#                                                  ObjectId('615858fe248bfd28abf84f07'),
#                                                  ObjectId('615858fe248bfd656cf84f11'),
#                                                  ObjectId('615858fe248bfd4a7bf84f1b'),
#                                                  ObjectId('61586006248bfd53d7f84f3d'),
#                                                  ObjectId('61586006248bfd800ff84f47'),
#                                                  ObjectId('61586006248bfdb4a6f84f51'),
#                                                  ObjectId('6158751e248bfd40d1f84fbb'),
#                                                  ObjectId('61588a36248bfd7052f8501f'),
#                                                  ObjectId('61589f4e248bfd4046f85061'),
#                                                  ObjectId('6158b466248bfd5636f850a5'),
#                                                  ObjectId('6158c97d248bfd7932f850ef'),
#                                                  ObjectId('6159480e248bfd2790f85195'),
#                                                  ObjectId('61596b36248bfde931f851d2'),
#                                                  ObjectId('615b505eae203564572d9c1d')],
#                                     'contributionCount': 45}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.022222222222222223},
#   'createdAt': datetime.datetime(2021, 10, 1, 11, 35, 1, 967000),
#   'name': 'muneve',
#   'score': 1.606646335823906e-05,
#   'updatedAt': datetime.datetime(2021, 10, 4, 19, 5, 2, 405000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.03947518659611431,
#                  'contributions': [{'_id': ObjectId('614addffec903a9d987eb580'),
#                                     'contents': [ObjectId('6162a5b5a52e723df817156b'),
#                                                  ObjectId('6162ec05a52e72f657171651')],
#                                     'contributionCount': 2}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.5},
#   'createdAt': datetime.datetime(2021, 10, 10, 8, 35, 1, 247000),
#   'name': 'worldmentalhealthday',
#   'score': 0.019737593298057157,
#   'updatedAt': datetime.datetime(2021, 10, 10, 13, 35, 1, 675000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615a371d248bfdcbf8f85416'),
#                                                  ObjectId('615b1820ae20356cca2d9aa7')],
#                                     'contributionCount': 2}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.5},
#   'createdAt': datetime.datetime(2021, 10, 3, 23, 5, 1, 104000),
#   'name': 'villarreal',
#   'score': 0.33100209050837104,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61632b4da52e721512171731'),
#                                                  ObjectId('61632b4da52e72b601171739'),
#                                                  ObjectId('61633255a52e7239de171771'),
#                                                  ObjectId('6163facc17d8253607079447'),
#                                                  ObjectId('6163face17d825f050079457'),
#                                                  ObjectId('6163ff7d17d82576a4079501'),
#                                                  ObjectId('6163ff7f17d8258e31079511')],
#                                     'contributionCount': 7}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.14285714285714285},
#   'createdAt': datetime.datetime(2021, 10, 10, 18, 5, 1, 739000),
#   'name': 'spurs',
#   'score': 0.09457202585953457,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('6156cf3d8bcb9777bd4878c5'),
#                                                  ObjectId('615746c4248bfd5652f8483a'),
#                                                  ObjectId('61580ef1248bfd4e21f84b43'),
#                                                  ObjectId('61580ef5248bfd0133f84b5b'),
#                                                  ObjectId('61584aed248bfd0116f84e9f'),
#                                                  ObjectId('61587c25248bfdfd13f84fd5'),
#                                                  ObjectId('6158d78c248bfd4270f85101'),
#                                                  ObjectId('615ee97516db738fc4a600eb'),
#                                                  ObjectId('61601ed5a52e72272b170c1d'),
#                                                  ObjectId('61601ed5a52e722f6b170c25'),
#                                                  ObjectId('61608f55a52e7259c5170f33'),
#                                                  ObjectId('6161a895a52e72c3f31712a3'),
#                                                  ObjectId('61631635a52e725c851716ff'),
#                                                  ObjectId('6164448d17d8250448079723'),
#                                                  ObjectId('61680eddf48bc2079014a58e'),
#                                                  ObjectId('61680edef48bc22a5514a598'),
#                                                  ObjectId('61680edef48bc2fdb314a5b6'),
#                                                  ObjectId('616823f569973eca6f167d68')],
#                                     'contributionCount': 18}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.05555555555555555},
#   'createdAt': datetime.datetime(2021, 10, 1, 9, 5, 1, 449000),
#   'name': 'fcb',
#   'score': 0.03677801005648567,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61586e15248bfd458af84f83'),
#                                                  ObjectId('615ccc0dae203585222da4d6')],
#                                     'contributionCount': 2}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.5},
#   'createdAt': datetime.datetime(2021, 10, 2, 14, 35, 1, 624000),
#   'name': 'asroma',
#   'score': 0.33100209050837104,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.5876154462021451,
#                  'contributions': [{'_id': ObjectId('614addffec903a9d987eb580'),
#                                     'contents': [ObjectId('61680edff48bc27dc614a5c0')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 14, 11, 5, 3, 489000),
#   'name': 'throwbackthursday',
#   'score': 0.5876154462021451,
#   'updatedAt': datetime.datetime(2021, 10, 14, 11, 5, 3, 489000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615bceedae203546fe2d9e45')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 5, 4, 5, 1, 124000),
#   'name': 'af',
#   'score': 0.6620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.8073493515704839,
#                  'contributions': [{'_id': ObjectId('614addffec903a9d987eb580'),
#                                     'contents': [ObjectId('6157239e248bfda510f846d9'),
#                                                  ObjectId('615731b0248bfd0488f84781'),
#                                                  ObjectId('61589f4e248bfd4046f85061'),
#                                                  ObjectId('6158de96248bfd550af85119'),
#                                                  ObjectId('616017cda52e72b271170be3'),
#                                                  ObjectId('616025dea52e728756170c6d'),
#                                                  ObjectId('6160500ea52e720bba170dab'),
#                                                  ObjectId('6160965ea52e72b972170f65'),
#                                                  ObjectId('61624345a52e7262e11714cd'),
#                                                  ObjectId('616564d5cf52e678cefca613'),
#                                                  ObjectId('61680ee0f48bc24b9c14a5e1'),
#                                                  ObjectId('6168a98e6ee6fb493d956458')],
#                                     'contributionCount': 12}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.08333333333333333},
#   'createdAt': datetime.datetime(2021, 10, 1, 15, 5, 2, 144000),
#   'name': 'pl',
#   'score': 0.06727911263087366,
#   'updatedAt': datetime.datetime(2021, 10, 14, 22, 5, 2, 403000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61632b4da52e721512171731'),
#                                                  ObjectId('61632b4da52e72b601171739'),
#                                                  ObjectId('61633255a52e726847171769'),
#                                                  ObjectId('61633255a52e7239de171771'),
#                                                  ObjectId('6163facc17d8253607079447'),
#                                                  ObjectId('6163facd17d825540507944f'),
#                                                  ObjectId('6163face17d825f050079457'),
#                                                  ObjectId('6163ff7d17d82576a4079501'),
#                                                  ObjectId('6163ff7e17d825029b079509'),
#                                                  ObjectId('6163ff7f17d8258e31079511')],
#                                     'contributionCount': 10}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.1},
#   'createdAt': datetime.datetime(2021, 10, 10, 18, 5, 1, 739000),
#   'name': 'thfc',
#   'score': 0.06620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.5876212682266743,
#                  'contributions': [{'_id': ObjectId('614addffec903a9d987eb580'),
#                                     'contents': [ObjectId('61680ee0f48bc24b9c14a5e1')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 14, 11, 5, 4, 724000),
#   'name': 'leimun',
#   'score': 0.5876212682266743,
#   'updatedAt': datetime.datetime(2021, 10, 14, 11, 5, 4, 724000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61601a26a52e7228f0170bfd')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 8, 10, 15, 2, 59000),
#   'name': '683',
#   'score': 0.6620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615bceedae203546fe2d9e45'),
#                                                  ObjectId('615ccc0dae20351f6b2da4ce'),
#                                                  ObjectId('6160a46da52e72ed2d170faf'),
#                                                  ObjectId('616106dda52e724c0f1710f5')],
#                                     'contributionCount': 4}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.25},
#   'createdAt': datetime.datetime(2021, 10, 5, 4, 5, 1, 124000),
#   'name': 'inter',
#   'score': 0.16550104525418552,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61612fe1a52e72da8f171117')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 9, 6, 0, 1, 603000),
#   'name': 'treemillions',
#   'score': 0.6620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61580563248bfd7807f84b10')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 2, 7, 8, 19, 992000),
#   'name': 'btt',
#   'score': 0.6620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.005303879716508798,
#                  'contributions': [{'_id': ObjectId('614addffec903a9d987eb580'),
#                                     'contents': [ObjectId('615f1aae4f989b34394c2547')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 7, 16, 5, 2, 298000),
#   'name': 'navaratri',
#   'score': 0.005303879716508798,
#   'updatedAt': datetime.datetime(2021, 10, 7, 16, 5, 2, 298000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('6157b295248bfdfd32f84a38'),
#                                                  ObjectId('61581bb2248bfd4184f84c15')],
#                                     'contributionCount': 2}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.5},
#   'createdAt': datetime.datetime(2021, 10, 2, 1, 15, 1, 422000),
#   'name': '5',
#   'score': 0.33100209050837104,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('6158d78d248bfdedf4f85109')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 2, 22, 5, 1, 359000),
#   'name': 'ibrahimovic',
#   'score': 0.6620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('6156dfa58bcb97b14548793f')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 1, 10, 15, 1, 818000),
#   'name': '676',
#   'score': 0.6620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('6159cc79248bfd1f44f852f2')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
# ...
#                                                  ObjectId('6163c5fda52e7265ff17189b'),
#                                                  ObjectId('6163db1625d485effafc98c9'),
#                                                  ObjectId('6163f02d25d485b45ffc9a0b'),
#                                                  ObjectId('6163fad717d825939807946f'),
#                                                  ObjectId('6163fad817d825759a079479'),
#                                                  ObjectId('6163fada17d825e87a079483'),
#                                                  ObjectId('6163fadd17d825aaff07948d'),
#                                                  ObjectId('6163fade17d8256c57079497'),
#                                                  ObjectId('6163ff8817d8257fd7079529'),
#                                                  ObjectId('6163ff8917d8256028079533'),
#                                                  ObjectId('6163ff8b17d825444207953d'),
#                                                  ObjectId('6163ff8e17d8255dc7079547'),
#                                                  ObjectId('6163ff8f17d82507c4079551'),
#                                                  ObjectId('6164054517d825cdfb07958b'),
#                                                  ObjectId('6164135617d8259d5d0795ed'),
#                                                  ObjectId('6164216617d8256dae07962f'),
#                                                  ObjectId('6164367e17d825a5ea0796c9'),
#                                                  ObjectId('61644b9517d8256f8a079743'),
#                                                  ObjectId('616460ae17d825ca340797b5'),
#                                                  ObjectId('616467b617d8251c6507980f'),
#                                                  ObjectId('61646ebe17d825c16d079841'),
#                                                  ObjectId('61646ebf17d825ab9207984b'),
#                                                  ObjectId('61646ec017d82558e3079855'),
#                                                  ObjectId('616483d517d825555e0798ef'),
#                                                  ObjectId('616491e617d8252b20079959'),
#                                                  ObjectId('6164a6fd17d82556df0799b3'),
#                                                  ObjectId('6164bc1617d8257471079a35'),
#                                                  ObjectId('6164df3d17d8257974079ab7'),
#                                                  ObjectId('616502650be74418f0fc9a13'),
#                                                  ObjectId('61652c96af656fc1019c8ef1'),
#                                                  ObjectId('616556c5af656f50bd9c8fd5'),
#                                                  ObjectId('616564d5cf52e678cefca613'),
#                                                  ObjectId('616579ee81952a3d5f2c33bf'),
#                                                  ObjectId('616587fe81952a7ff52c3424'),
#                                                  ObjectId('61659d1681952a329b2c350b'),
#                                                  ObjectId('61680edff48bc27dc614a5c0'),
#                                                  ObjectId('61680edff48bc2935614a5cb'),
#                                                  ObjectId('61680edff48bc266c014a5d6'),
#                                                  ObjectId('61680ee0f48bc24b9c14a5e1'),
#                                                  ObjectId('61680ee1f48bc2eb6314a5ec'),
#                                                  ObjectId('61681cee69973eff0c167d2b'),
#                                                  ObjectId('6168320569973eb719167e30'),
#                                                  ObjectId('6168401669973e381e167ed1'),
#                                                  ObjectId('6168471e6ee6fb509b9560c4'),
#                                                  ObjectId('61685c366ee6fbba6795618d'),
#                                                  ObjectId('61685c376ee6fb1534956198'),
#                                                  ObjectId('61686a466ee6fb93d0956257'),
#                                                  ObjectId('616878566ee6fb35b89562b2'),
#                                                  ObjectId('616886656ee6fb261195633f'),
#                                                  ObjectId('6168a98e6ee6fb493d956458'),
#                                                  ObjectId('6168d3be6ee6fb3141956521'),
#                                                  ObjectId('6168fded6ee6fb3f0a9565e0')],
#                                     'contributionCount': 235}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.00823045267489712},
#   'createdAt': datetime.datetime(2021, 10, 1, 8, 5, 2, 427000),
#   'name': 'mufc',
#   'score': 0.007902052488043007,
#   'updatedAt': datetime.datetime(2021, 10, 15, 4, 5, 1, 596000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615f2fc54f989b0f9d4c25d1'),
#                                                  ObjectId('615f2fc64f989b23f24c25d9'),
#                                                  ObjectId('616823f569973e7ef9167d72')],
#                                     'contributionCount': 3}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.3333333333333333},
#   'createdAt': datetime.datetime(2021, 10, 7, 17, 35, 1, 798000),
#   'name': 'newcastle',
#   'score': 0.220668060338914,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615fc28b4f989b35ec4c292e')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 8, 4, 1, 15, 297000),
#   'name': 'blockchain',
#   'score': 0.6620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6595705501275686,
#                  'contributions': [{'_id': ObjectId('614addffec903a9d987eb580'),
#                                     'contents': [ObjectId('615908c5248bfde812f85163'),
#                                                  ObjectId('615b5e6eae203536d62d9c67'),
#                                                  ObjectId('615b8196ae20352e122d9d31'),
#                                                  ObjectId('615ba4beae2035077c2d9db3'),
#                                                  ObjectId('615de54ddb45d0948b925815'),
#                                                  ObjectId('615e2495db45d0c0589259c1'),
#                                                  ObjectId('615f059516db733794a601dd'),
#                                                  ObjectId('6164df3d17d8257974079ab7'),
#                                                  ObjectId('6168471e6ee6fb509b9560c4')],
#                                     'contributionCount': 9}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.1111111111111111},
#   'createdAt': datetime.datetime(2021, 10, 3, 1, 35, 1, 627000),
#   'name': 'muacademy',
#   'score': 0.07328561668084095,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 5, 2, 452000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.00012597519138293675,
#                  'contributions': [{'_id': ObjectId('614addffec903a9d987eb580'),
#                                     'contents': [ObjectId('6157fd96248bfd3068f84a9e')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 2, 6, 35, 2, 24000),
#   'name': 'unitedreview',
#   'score': 0.00012597519138293675,
#   'updatedAt': datetime.datetime(2021, 10, 2, 6, 35, 2, 24000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('6161cbbda52e72066b171375')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 9, 17, 5, 1, 635000),
#   'name': 'ps',
#   'score': 0.6620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61581d3e248bfd3830f84c9d'),
#                                                  ObjectId('61581d40248bfd8955f84ca5'),
#                                                  ObjectId('61581d41248bfd9d4df84cad'),
#                                                  ObjectId('61581d44248bfd5e83f84cb5'),
#                                                  ObjectId('615fc2864f989b34fa4c291e'),
#                                                  ObjectId('615fc28b4f989b35ec4c292e')],
#                                     'contributionCount': 6}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.16666666666666666},
#   'createdAt': datetime.datetime(2021, 10, 2, 8, 50, 6, 186000),
#   'name': 'crypto',
#   'score': 0.110334030169457,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('614addffec903a9d987eb580'),
#                                     'contents': [ObjectId('615d5fb6ae20355cd82da635'),
#                                                  ObjectId('615dd035db45d006c392576b'),
#                                                  ObjectId('615e0f7edb45d016fc925945'),
#                                                  ObjectId('615f60fd4f989bff1c4c273f'),
#                                                  ObjectId('61607336a52e72ef1a170e87'),
#                                                  ObjectId('616290a5a52e723a7e171519'),
#                                                  ObjectId('6163476da52e72256a1717b9'),
#                                                  ObjectId('6163557da52e7211081717eb'),
#                                                  ObjectId('61635c87a52e7244da1717f5'),
#                                                  ObjectId('61635c87a52e72fe951717ff'),
#                                                  ObjectId('6163638ea52e72483b171811'),
#                                                  ObjectId('6163fad717d825939807946f'),
#                                                  ObjectId('6163fad817d825759a079479'),
#                                                  ObjectId('6163ff8817d8257fd7079529'),
#                                                  ObjectId('6163ff8917d8256028079533')],
#                                     'contributionCount': 15},
#                                    {'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615e016edb45d0f8ff9258db')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.125},
#   'createdAt': datetime.datetime(2021, 10, 6, 8, 35, 2, 535000),
#   'name': 'nationsleague',
#   'score': 0.08275052262709276,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61656026cf52e61a32fca5f5')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 12, 10, 15, 2, 340000),
#   'name': '686',
#   'score': 0.6620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61581d4b248bfdc215f84ce5')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 2, 8, 50, 19, 591000),
#   'name': 'solanasaturday',
#   'score': 0.6620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615c5485ae2035742c2da14c')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 5, 13, 35, 1, 689000),
#   'name': 'herewegopodcast',
#   'score': 0.6620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.0015997866865346453,
#                  'contributions': [{'_id': ObjectId('614addffec903a9d987eb580'),
#                                     'contents': [ObjectId('6157239e248bfda510f846d9'),
#                                                  ObjectId('61573fbd248bfd986ef847f8'),
#                                                  ObjectId('615cd316ae20357fc12da4f6')],
#                                     'contributionCount': 3}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.3333333333333333},
#   'createdAt': datetime.datetime(2021, 10, 1, 15, 5, 2, 144000),
#   'name': 'ucl',
#   'score': 0.0005332622288448817,
#   'updatedAt': datetime.datetime(2021, 10, 5, 22, 35, 2, 139000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('61581d40248bfd8955f84ca5'),
#                                                  ObjectId('61581d41248bfd9d4df84cad'),
#                                                  ObjectId('61581d47248bfd5498f84cbd')],
#                                     'contributionCount': 3}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 0.3333333333333333},
#   'createdAt': datetime.datetime(2021, 10, 2, 8, 50, 8, 443000),
#   'name': 'solsummer',
#   'score': 0.220668060338914,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('615c1c45ae2035edcb2d9fc8')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 5, 9, 35, 1, 692000),
#   'name': 'vlahovic',
#   'score': 0.6620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)},
#  {'__v': 0,
#   'aggregator': {'ageScore': 0.6620041810167421,
#                  'contributions': [{'_id': ObjectId('6149a7c33e6269b3adabc900'),
#                                     'contents': [ObjectId('6160b985a52e726690171021')],
#                                     'contributionCount': 1}],
#                  'engagementScore': 0,
#                  'hastagDiversityScore': 1.0},
#   'createdAt': datetime.datetime(2021, 10, 8, 21, 35, 1, 652000),
#   'name': 'gnabry',
#   'score': 0.6620041810167421,
#   'updatedAt': datetime.datetime(2021, 10, 14, 15, 12, 41, 525000)}]
