# %% [markdown]
# ########################################################################################

# %% [markdown]
# ## Upsert creatorStats
# v2: collect only computed statistics without hashtag property (wait for 'contents' upgrade)

# %% [markdown]
# ########################################################################################

# %% [markdown]
# ## (optional) libraries in trigger function

# %%
import pymongo # connect to MongoDB
from pymongo import MongoClient
from IPython.display import clear_output # clear output everytime running
from pprint import pprint

# %% [markdown]
# ## mandatory libraries in trigger function

# %%
import json
import sys
# from mongo_client import mongo_client
from bson.objectid import ObjectId
from bson import regex
from datetime import datetime, timedelta
import re
import math

# %%
# connect to MongoDB
## define connection URI as role; analytics-admin
connectionUri = 'mongodb+srv://analytics-admin:pnYT55BGWwHePK1M@dev-cluster.fg2e5.mongodb.net/myFirstDatabase?retryWrites=true&w=majority'

## assign client
client = pymongo.MongoClient(connectionUri)

## assign databases
appDb = client['app-db']
analyticsDb = client['analytics-db']

## assign collections
### source collections
contents = appDb['contents']

### destination collections
creatorStats = analyticsDb['creatorStats']
hashtagStats = analyticsDb['hashtagStats']

# %% [markdown]
# ########################################################################################

# %% [markdown]
# ########################################################################################

# %% [markdown]
# ## creator parsing using 'contents'

# %% [markdown]
# ### note!!!: Be careful! running this cell cause collection changes

# %% [markdown]
# ### below cell just for filtering in testing

# %%
# define content parameters
contentDateThreshold = 14
likedWeight = 1
commentedWeight = 1
recastedWeight = 1
quotedWeight = 1
followedWeight = 0.01
halfLifeHours = 24

# %%
# define cursor
creatorStatsCursor = [
    {
        # filter age of contents for only newer than specific days
        # filter only visible contents
        '$match': {
            'createdAt': {
                '$gte': (datetime.utcnow() - timedelta(days=contentDateThreshold)) 
            },
            'visibility': 'publish'
        }
    }, {
        # summarize to get summation of engagements for each content type & user
        '$group': {
            '_id': {
                'authorId': '$author.id', 
                'type': '$type'
            }, 
            'contentCount': {
                '$count': {}
            }, 
            'likedCount': {
                '$sum': '$engagements.like.count'
            }, 
            'commentedCount': {
                '$sum': '$engagements.comment.count'
            }, 
            'recastedCount': {
                '$sum': '$engagements.recast.count'
            }, 
            'quotedCount': {
                '$sum': '$engagements.quote.count'
            }, 
            'updatedAt': {
                '$max': '$updatedAt'
            }
        }
    }, {
        # add calculated fields
        '$addFields': {
            # age score: a decay value as time since last update time
            ## equation: ageScore = e^(-{\lambda}*t)
            'aggregator.ageScore': {
                '$exp': {
                    '$multiply': [
                        {
                            '$multiply': [
                                {
                                    '$divide': [
                                        {
                                            '$subtract': [
                                                datetime.utcnow(), '$updatedAt'
                                            ]
                                        }, 60 * 60 * 1000
                                    ]
                                }, {
                                    '$divide': [
                                        {
                                            '$ln': 2
                                        }, halfLifeHours
                                    ]
                                }
                            ]
                        }, -1
                    ]
                }
            }, 
            # engagement score: a linear combination result among type of available engagements
            ## equation: engagementScore = {\sigma}_{k}({\beta}_{k}*x_{k})
            'aggregator.engagementScore': {
                '$sum': [
                        {
                            '$multiply': [
                                '$commentedCount', commentedWeight
                            ]
                        }, {
                            '$multiply': [
                                '$recastedCount', recastedWeight
                            ]
                        }, {
                            '$multiply': [
                                '$quotedCount', quotedWeight
                            ]
                        }, {
                            '$multiply': [
                                '$quotedCount', quotedWeight
                            ]
                        # add bias = 1
                        }, 1
                    ]
            }
        }
    }, {
        # summarize to get summation of engagements for each user
        '$group': {
            '_id': '$_id.authorId', 
            'creatorContentCount': {
                '$sum': '$contentCount'
            }, 
            'creatorLikedCount': {
                '$sum': '$likeCount'
            }, 
            'creatorCommentedCount': {
                '$sum': '$commentCount'
            }, 
            'creatorRecastedCount': {
                '$sum': '$recastCount'
            }, 
            'creatorQuotedCount': {
                '$sum': '$quoteCount'
            }, 
            'updatedAt': {
                '$max': '$updatedAt'
            }, 
            'summary': {
                '$push': {
                    'type': '$_id.type', 
                    'typeCount': '$contentCount', 
                    'updatedAt': '$updatedAt', 
                    'aggregator': '$aggregator'
                }
            }
        }
    }, {
        # deconstruct object, named "summary" for furthor calculation
        '$unwind': {
            'path': '$summary', 
            'preserveNullAndEmptyArrays': True
        }
    }, {
        # calculate total engagementScore
        '$addFields': {
            'aggregator.engagementScore': {
                '$sum': [
                    {
                        '$multiply': [
                            '$creatorLikedCount', commentedWeight
                        ]
                    }, {
                        '$multiply': [
                            '$creatorLikedCount', recastedWeight
                        ]
                    }, {
                        '$multiply': [
                            '$creatorCommentedCount', quotedWeight
                        ]
                    }, {
                        '$multiply': [
                            '$creatorQuotedCount', quotedWeight
                        ]
                    # add bias = 1
                    }, 1
                ]
            }, 
            # calculate weights as fractions of content type per total contents
            ## equation: typeWeight(type) = n_{content|type}/N_{content}
            'summary.typeWeight': {
                '$divide': [
                    '$summary.typeCount', '$creatorContentCount'
                ]
            }
        }
    }, {
        # join with 'users' for more information
        '$lookup': {
            'from': 'users', 
            'localField': '_id', 
            'foreignField': '_id', 
            'as': 'userDetail'
        }
    }, {
        # filter for only publish users
        '$match': {
            'userDetail.visibility': 'publish'
        }
    }, {
        # calculate followed score then add to both aggregator
        ## equation: followedScore = (\gamma}*N_{follower}
        '$addFields': {
            'followedScore': {
                '$multiply': [
                    {
                        '$first': '$userDetail.followedCount'
                    }, followedWeight
                ]
            }
        }
    }, {
        # map intermediate result format
        '$project': {
            '_id': 1, 
            'creatorContentCount': 1, 
            'summary.type': 1, 
            'summary.typeCount': 1, 
            'summary.typeWeight': 1, 
            'summary.aggregator.ageScore': 1, 
            'summary.aggregator.engagementScore': 1, 
            'aggregator.engagementScore': 1, 
            'aggregator.followedScore': '$followedScore', 
            'lastContentUpdatedAt': '$updatedAt', 
            'summary.lastContentUpdatedAt': '$updatedAt', 
            'summary.aggregator.followedScore': '$followedScore',  
            'ownerAccount': {
                '$first': '$userDetail.ownerAccount'
            }, 
            'displayId': {
                '$first': '$userDetail.displayId'
            }, 
            'createdAt': {
                '$first': '$userDetail.createdAt'
            }, 
            'followedCount': {
                '$first': '$userDetail.followedCount'
            }, 
            'followerCount': {
                '$first': '$userDetail.followerCount'
            }, 
            'summary.aggregator.followedScore': '$followedScore', 
            # calculate creator score for each content type
            ## equation: score = ((typeWeight)*(ageScore)*(engagementScore_{type}/engagementScore)) + followedScore
            'summary.score': {
                '$add': [
                    {
                        '$multiply': [
                            '$summary.typeWeight', {
                                '$divide': [
                                    {
                                        '$add': [
                                            '$summary.aggregator.engagementScore', 1
                                        ]
                                    }, {
                                        '$add': [
                                            '$aggregator.engagementScore', 1
                                        ]
                                    }
                                ]
                            }, '$summary.aggregator.ageScore'
                        ]
                     }, '$followedScore'
                ]
            },
            'creatorLikedCount': '1',
            'creatorCommentedCount': '1',
            'creatorRecastedCount': '1',
            'creatorQuotedCount': '1'
        }
    }, {
        # summarize content type together
        '$group': {
            '_id': '$_id', 
            'ownerAccount': {
                '$max': '$ownerAccount'
            }, 
            'displayId': {
                '$max': '$displayId'
            }, 
            'userCreatedAt': {
                '$max': '$createdAt'
            }, 
            'lastContentUpdatedAt': {
                '$max': '$lastContentUpdatedAt'
            }, 
            'creatorContentCount': {
                '$max': '$creatorContentCount'
            }, 
            'followedCount': {
                '$max': '$followedCount'
            }, 
            'followerCount': {
                '$max': '$followerCount'
            }, 
            'aggregator': {
                '$max': '$aggregator'
            }, 
            'summary': {
                '$push': '$summary'
            }, 
            'ageScore': {
                '$max': '$summary.aggregator.ageScore'
            },
            'creatorLikedCount': {
                '$sum': '$creatorLikedCount'
            },
            'creatorCommentedCount': {
                '$sum': '$creatorCommentedCount'
            },
            'creatorRecastedCount': {
                '$sum': '$creatorRecastedCount'
            },
            'creatorQuotedCount': {
                '$sum': '$creatorQuotedCount'
            }
        }
    }, {
        # map final result format
        '$project': {
            '_id': 1, 
            'ownerAccount': 1, 
            'displayId': 1, 
            'userCreatedAt': 1, 
            'lastContentUpdatedAt': 1, 
            'followedCount': 1, 
            'followerCount': 1, 
            'summary': 1, 
            'contentCount': '$creatorContentCount', 
            'aggregator.ageScore': '$ageScore', 
            'aggregator.engagementScore': '$aggregator.engagementScore', 
            'aggregator.followedScore': '$aggregator.followedScore', 
            # calculate overall creator score
            ## equation: score = (ageScore*(engagementScore_{type}/engagementScore)) + (followedScore + bias)
            'score': {
                '$add': [
                    {
                        '$multiply': [
                            {
                                '$divide': [
                                    '$aggregator.engagementScore', '$creatorContentCount'
                                ]
                            }, '$ageScore'
                        ]
                    }, {
                        '$add': [
                            '$aggregator.followedScore', followedWeight
                        ]
                    }
                ]
            },
            'creatorLikedCount': '$creatorLikedCount',
            'creatorCommentedCount': '$creatorCommentedCount',
            'creatorRecastedCount': '$creatorRecastedCount',
            'creatorQuotedCount': '$creatorQuotedCount'
        }
#     }, {
#         # upsert to 'userStats' collection
#         '$merge': {
#             'into': {
#                 'db': 'analytics-db', 
#                 'coll': 'creatorStats'
#             }, 
#             'on': '_id', 
#             'whenMatched': 'replace', 
#             'whenNotMatched': 'insert'
#         }
    }
]

# %%
# clear the output
clear_output()

# print output
pprint(list(contents.aggregate(creatorStatsCursor)))
# Out:
# [{'_id': ObjectId('6170067a51db852fb36d2109'),
#   'aggregator': {'ageScore': 0.999120074397398,
#                  'engagementScore': 1,
#                  'followedScore': 0.02},
#   'contentCount': 945,
#   'creatorCommentedCount': 0,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'displayId': 'JulapongCastcle',
#   'followedCount': 2,
#   'followerCount': 1,
#   'lastContentUpdatedAt': datetime.datetime(2021, 11, 1, 10, 0, 21, 747000),
#   'ownerAccount': ObjectId('6170063351db852b0e6d20fc'),
#   'score': 0.031057269919997247,
#   'summary': [{'aggregator': {'ageScore': 0.949884155815001,
#                               'engagementScore': 1,
#                               'followedScore': 0.02},
#                'lastContentUpdatedAt': datetime.datetime(2021, 11, 1, 10, 0, 21, 747000),
#                'score': 0.05719123149751856,
#                'type': 'image',
#                'typeCount': 37,
#                'typeWeight': 0.039153439153439155},
#               {'aggregator': {'ageScore': 0.8680849506407436,
#                               'engagementScore': 1,
#                               'followedScore': 0.02},
#                'lastContentUpdatedAt': datetime.datetime(2021, 11, 1, 10, 0, 21, 747000),
#                'score': 0.023674433653505793,
#                'type': 'blog',
#                'typeCount': 4,
#                'typeWeight': 0.004232804232804233},
#               {'aggregator': {'ageScore': 0.999120074397398,
#                               'engagementScore': 2,
#                               'followedScore': 0.02},
#                'lastContentUpdatedAt': datetime.datetime(2021, 11, 1, 10, 0, 21, 747000),
#                'score': 1.4536580115162665,
#                'type': 'short',
#                'typeCount': 904,
#                'typeWeight': 0.9566137566137566}],
#   'userCreatedAt': datetime.datetime(2021, 10, 20, 12, 7, 22, 571000)},
#  {'_id': ObjectId('61710e033e00f69cbfabd308'),
#   'aggregator': {'ageScore': 0.06048599960912863,
#                  'engagementScore': 1,
#                  'followedScore': 0.0},
#   'contentCount': 1,
#   'creatorCommentedCount': 0,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'displayId': 'maxcpage',
#   'followedCount': 0,
#   'followerCount': 1,
#   'lastContentUpdatedAt': datetime.datetime(2021, 10, 28, 8, 54, 8, 650000),
#   'ownerAccount': ObjectId('6170daf8e5ddcb8ae504e798'),
#   'score': 0.07048599960912863,
#   'summary': [{'aggregator': {'ageScore': 0.06048599960912863,
#                               'engagementScore': 1,
#                               'followedScore': 0.0},
#                'lastContentUpdatedAt': datetime.datetime(2021, 10, 28, 8, 54, 8, 650000),
#                'score': 0.06048599960912863,
#                'type': 'short',
#                'typeCount': 1,
#                'typeWeight': 1.0}],
#   'userCreatedAt': datetime.datetime(2021, 10, 21, 6, 51, 47, 246000)},
#  {'_id': ObjectId('6176d67d19931a03b248c5ab'),
#   'aggregator': {'ageScore': 0.9500891383755857,
#                  'engagementScore': 1,
#                  'followedScore': 0.0},
#   'contentCount': 31,
#   'creatorCommentedCount': 0,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'displayId': 'JulapongInstagram',
#   'followedCount': 0,
#   'followerCount': 0,
#   'lastContentUpdatedAt': datetime.datetime(2021, 11, 1, 8, 15, 49, 522000),
#   'ownerAccount': ObjectId('6170063351db852b0e6d20fc'),
#   'score': 0.04064803672179309,
#   'summary': [{'aggregator': {'ageScore': 0.9500891383755857,
#                               'engagementScore': 1,
#                               'followedScore': 0.0},
#                'lastContentUpdatedAt': datetime.datetime(2021, 11, 1, 8, 15, 49, 522000),
#                'score': 0.9500891383755857,
#                'type': 'image',
#                'typeCount': 31,
#                'typeWeight': 1.0}],
#   'userCreatedAt': datetime.datetime(2021, 10, 25, 16, 8, 29, 595000)},
#  {'_id': ObjectId('6170eb21e5ddcb429e04e7d7'),
#   'aggregator': {'ageScore': 0.9627173923467776,
#                  'engagementScore': 1,
#                  'followedScore': 0.0},
#   'contentCount': 4,
#   'creatorCommentedCount': 0,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'displayId': 'tanakorn',
#   'followedCount': 0,
#   'followerCount': 0,
#   'lastContentUpdatedAt': datetime.datetime(2021, 11, 1, 8, 43, 15, 397000),
#   'ownerAccount': ObjectId('6170daf8e5ddcb8ae504e798'),
#   'score': 0.2506793480866944,
#   'summary': [{'aggregator': {'ageScore': 0.9627173923467776,
#                               'engagementScore': 1,
#                               'followedScore': 0.0},
#                'lastContentUpdatedAt': datetime.datetime(2021, 11, 1, 8, 43, 15, 397000),
#                'score': 0.9627173923467776,
#                'type': 'short',
#                'typeCount': 4,
#                'typeWeight': 1.0}],
#   'userCreatedAt': datetime.datetime(2021, 10, 21, 4, 22, 57, 161000)},
#  {'_id': ObjectId('6176d64119931a7a0f48c59c'),
#   'aggregator': {'ageScore': 0.525448503354424,
#                  'engagementScore': 1,
#                  'followedScore': 0.0},
#   'contentCount': 11,
#   'creatorCommentedCount': 0,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'displayId': 'JulapongYoutube',
#   'followedCount': 0,
#   'followerCount': 0,
#   'lastContentUpdatedAt': datetime.datetime(2021, 10, 31, 11, 45, 19, 556000),
#   'ownerAccount': ObjectId('6170063351db852b0e6d20fc'),
#   'score': 0.05776804575949309,
#   'summary': [{'aggregator': {'ageScore': 0.525448503354424,
#                               'engagementScore': 1,
#                               'followedScore': 0.0},
#                'lastContentUpdatedAt': datetime.datetime(2021, 10, 31, 11, 45, 19, 556000),
#                'score': 0.525448503354424,
#                'type': 'short',
#                'typeCount': 11,
#                'typeWeight': 1.0}],
#   'userCreatedAt': datetime.datetime(2021, 10, 25, 16, 7, 29, 226000)},
#  {'_id': ObjectId('61700a6151db852fd36d2142'),
#   'aggregator': {'ageScore': 0.12753042516458804,
#                  'engagementScore': 1,
#                  'followedScore': 0.01},
#   'contentCount': 2,
#   'creatorCommentedCount': 0,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'displayId': 'sklim29',
#   'followedCount': 1,
#   'followerCount': 0,
#   'lastContentUpdatedAt': datetime.datetime(2021, 10, 29, 10, 43, 49, 593000),
#   'ownerAccount': ObjectId('617009b551db8539406d2126'),
#   'score': 0.08376521258229402,
#   'summary': [{'aggregator': {'ageScore': 0.12753042516458804,
#                               'engagementScore': 1,
#                               'followedScore': 0.01},
#                'lastContentUpdatedAt': datetime.datetime(2021, 10, 29, 10, 43, 49, 593000),
#                'score': 0.13753042516458805,
#                'type': 'short',
#                'typeCount': 2,
#                'typeWeight': 1.0}],
#   'userCreatedAt': datetime.datetime(2021, 10, 20, 12, 24, 1, 677000)},
#  {'_id': ObjectId('6176d62d19931a40ea48c597'),
#   'aggregator': {'ageScore': 0.9992883013708482,
#                  'engagementScore': 1,
#                  'followedScore': 0.0},
#   'contentCount': 509,
#   'creatorCommentedCount': 0,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'displayId': 'JulapongTwitter',
#   'followedCount': 0,
#   'followerCount': 0,
#   'lastContentUpdatedAt': datetime.datetime(2021, 11, 1, 10, 0, 42, 733000),
#   'ownerAccount': ObjectId('6170063351db852b0e6d20fc'),
#   'score': 0.011963238313105792,
#   'summary': [{'aggregator': {'ageScore': 0.9992883013708482,
#                               'engagementScore': 2,
#                               'followedScore': 0.0},
#                'lastContentUpdatedAt': datetime.datetime(2021, 11, 1, 10, 0, 42, 733000),
#                'score': 1.4989324520562723,
#                'type': 'short',
#                'typeCount': 509,
#                'typeWeight': 1.0}],
#   'userCreatedAt': datetime.datetime(2021, 10, 25, 16, 7, 9, 635000)},
#  {'_id': ObjectId('617fa018b6ebda03df17ae7b'),
#   'aggregator': {'ageScore': 0.9841746578344289,
#                  'engagementScore': 1,
#                  'followedScore': 0.0},
#   'contentCount': 1,
#   'creatorCommentedCount': 0,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'displayId': 'testapp01',
#   'followedCount': 0,
#   'followerCount': 0,
#   'lastContentUpdatedAt': datetime.datetime(2021, 11, 1, 9, 29, 3, 91000),
#   'ownerAccount': ObjectId('617f9f25b6ebda93bb17ae59'),
#   'score': 0.9941746578344289,
#   'summary': [{'aggregator': {'ageScore': 0.9841746578344289,
#                               'engagementScore': 1,
#                               'followedScore': 0.0},
#                'lastContentUpdatedAt': datetime.datetime(2021, 11, 1, 9, 29, 3, 91000),
#                'score': 0.9841746578344289,
#                'type': 'short',
#                'typeCount': 1,
#                'typeWeight': 1.0}],
#   'userCreatedAt': datetime.datetime(2021, 11, 1, 8, 6, 48, 668000)},
#  {'_id': ObjectId('6176d61319931a29ba48c592'),
#   'aggregator': {'ageScore': 0.9992244333497782,
#                  'engagementScore': 1,
#                  'followedScore': 0.0},
#   'contentCount': 278,
#   'creatorCommentedCount': 0,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'displayId': 'JulapongRssFeed',
#   'followedCount': 0,
#   'followerCount': 0,
#   'lastContentUpdatedAt': datetime.datetime(2021, 11, 1, 10, 0, 34, 766000),
#   'ownerAccount': ObjectId('6170063351db852b0e6d20fc'),
#   'score': 0.01359433249406395,
#   'summary': [{'aggregator': {'ageScore': 0.9992244333497782,
#                               'engagementScore': 3,
#                               'followedScore': 0.0},
#                'lastContentUpdatedAt': datetime.datetime(2021, 11, 1, 10, 0, 34, 766000),
#                'score': 1.9984488666995563,
#                'type': 'short',
#                'typeCount': 278,
#                'typeWeight': 1.0}],
#   'userCreatedAt': datetime.datetime(2021, 10, 25, 16, 6, 43, 455000)},
#  {'_id': ObjectId('6176d66719931a76d848c5a1'),
#   'aggregator': {'ageScore': 0.9636617440150042,
#                  'engagementScore': 1,
#                  'followedScore': 0.0},
#   'contentCount': 8,
#   'creatorCommentedCount': 0,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'displayId': 'JulapongFacebook',
#   'followedCount': 0,
#   'followerCount': 1,
#   'lastContentUpdatedAt': datetime.datetime(2021, 11, 1, 8, 45, 17, 608000),
#   'ownerAccount': ObjectId('6170063351db852b0e6d20fc'),
#   'score': 0.13045771800187553,
#   'summary': [{'aggregator': {'ageScore': 0.9636617440150042,
#                               'engagementScore': 1,
#                               'followedScore': 0.0},
#                'lastContentUpdatedAt': datetime.datetime(2021, 11, 1, 8, 45, 17, 608000),
#                'score': 0.9636617440150042,
#                'type': 'blog',
#                'typeCount': 8,
#                'typeWeight': 1.0}],
#   'userCreatedAt': datetime.datetime(2021, 10, 25, 16, 8, 7, 331000)},
#  {'_id': ObjectId('6176d66e19931af9b448c5a6'),
#   'aggregator': {'ageScore': 0.5180379308022415,
#                  'engagementScore': 1,
#                  'followedScore': 0.0},
#   'contentCount': 22,
#   'creatorCommentedCount': 0,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'displayId': 'JulapongMedium',
#   'followedCount': 0,
#   'followerCount': 0,
#   'lastContentUpdatedAt': datetime.datetime(2021, 10, 31, 11, 15, 49, 78000),
#   'ownerAccount': ObjectId('6170063351db852b0e6d20fc'),
#   'score': 0.03354717867282916,
#   'summary': [{'aggregator': {'ageScore': 0.5180379308022415,
#                               'engagementScore': 1,
#                               'followedScore': 0.0},
#                'lastContentUpdatedAt': datetime.datetime(2021, 10, 31, 11, 15, 49, 78000),
#                'score': 0.5180379308022415,
#                'type': 'short',
#                'typeCount': 22,
#                'typeWeight': 1.0}],
#   'userCreatedAt': datetime.datetime(2021, 10, 25, 16, 8, 14, 182000)}]
