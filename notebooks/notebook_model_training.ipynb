# %% [markdown]
# # model training
# v1: train then update all collection

# %% [markdown]
# ## (optional) libraries in trigger function

# %%
import pymongo # connect to MongoDB
from pymongo import MongoClient
from IPython.display import clear_output # clear output everytime running
from pprint import pprint

# %% [markdown]
# ## mandatory libraries in trigger function

# %%
import json
import sys
# from mongo_client import mongo_client
from bson.objectid import ObjectId
from bson import regex
from datetime import datetime, timedelta
import re
import math

import pickle
import numpy as np
import pandas as pd

# %%
# connect to MongoDB
## define connection URI as role; analytics-admin
connectionUri = 'mongodb+srv://analytics-admin:pnYT55BGWwHePK1M@dev-cluster.fg2e5.mongodb.net/myFirstDatabase?retryWrites=true&w=majority'

## assign client
client = pymongo.MongoClient(connectionUri)

## assign databases
appDb = client['app-db']
analyticsDb = client['analytics-db']

## assign collections
### source collections
contents = appDb['contents']
relationships = appDb['relationships']
users = appDb['users']

### destination collections
creatorStats = analyticsDb['creatorStats']
hashtagStats = analyticsDb['hashtagStats']
contentStats = analyticsDb['contentStats']
mlArtifacts = analyticsDb['mlArtifacts']

# %%
# define content parameters
updatedAtThreshold = 14

# %%
datasetCursor = [
    {
        # filter age of contents for only newer than specific days
        # filter only visible contents
        '$match': {
            'updatedAt': {
                '$gte': (datetime.utcnow() - timedelta(days=contentDateThreshold)) 
            }
        }
    }, {
        '$lookup': {
            'from': 'creatorStats', 
            'localField': 'authorId', 
            'foreignField': '_id', 
            'as': 'userStats'
        }
    }, {
        '$unwind': {
            'path': '$userStats', 
            'preserveNullAndEmptyArrays': True
        }
    }, {
        '$project': {
            '_id': 1,
            'likeCount': 1,
            'commentCount': 1,
            'recastCount': 1,
            'quoteCount': 1,
            'photoCount': 1,
            'characterLength': 1,
            'creatorContentCount' :'$userStats.contentCount',
            'creatorLikedCount': '$userStats.creatorLikedCount',
            'creatorCommentedCount': '$userStats.creatorCommentedCount',
            'creatorRecastedCount': '$userStats.creatorRecastedCount',
            'creatorQuotedCount': '$userStats.creatorQuotedCount',
            'ageScore': '$aggregator.ageScore'
        }
    }
]

# %%
# clear the output
clear_output()

# print output
pprint(list(contentStats.aggregate(datasetCursor)))
# Out:
# [{'_id': ObjectId('617a3fe741824b8714ae9be5'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 284,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a3fe941824b869eae9bf1'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 201,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a3fed41824b1eb9ae9bfd'),
#   'ageScore': 0.03261982618972318,
#   'characterLength': 284,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a3fef41824b762cae9c06'),
#   'ageScore': 0.03262022606023386,
#   'characterLength': 201,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a46ed41824b7404ae9c0f'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 61,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a46ef41824ba820ae9c1b'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 124,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a46f041824b37a3ae9c27'),
#   'ageScore': 0.0330930345713122,
#   'characterLength': 61,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 578,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a46f341824b0221ae9c30'),
#   'ageScore': 0.033093729631661926,
#   'characterLength': 124,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a54fe41824bca2cae9c39'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 169,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a550041824baedfae9c45'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 295,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a550441824b2127ae9c51'),
#   'ageScore': 0.034063708721418784,
#   'characterLength': 169,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a550641824b8b34ae9c5a'),
#   'ageScore': 0.03406416919687796,
#   'characterLength': 295,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a59ad41824b684aae9c63'),
#   'ageScore': 0.03439130837044058,
#   'characterLength': 289,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a5c0641824b6f66ae9c6c'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 216,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a5c0a41824bbcc5ae9c78'),
#   'ageScore': 0.03455866552458574,
#   'characterLength': 216,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a6530ad62571922d72f67'),
#   'ageScore': 0.03521416056280903,
#   'characterLength': 14,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a6a18ad62570f1ad72f75'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 183,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a6a1aad62575ad3d72f81'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 34,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a6a1cad62575e91d72f8d'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 195,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a6a21ad6257f43bd72f99'),
#   'ageScore': 0.0355732631482103,
#   'characterLength': 183,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a6a23ad62575a79d72fa2'),
#   'ageScore': 0.03557377542302337,
#   'characterLength': 34,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a6a24ad6257e39fd72fab'),
#   'ageScore': 0.03557427315001877,
#   'characterLength': 195,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a6d2cad625780bad72fb7'),
#   'ageScore': 0.0742465512252415,
#   'characterLength': 0,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 2,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 2,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a6d3dad62574baed72fc0'),
#   'ageScore': 0.07352865380745216,
#   'characterLength': 10,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 5,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a711fad6257cae9d72fc9'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 84,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a7121ad62573498d72fd5'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 245,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a7126ad6257826cd72fe1'),
#   'ageScore': 0.03608975268754267,
#   'characterLength': 84,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a7127ad6257d76cd72fea'),
#   'ageScore': 0.03609021854652286,
#   'characterLength': 245,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a7827ad6257292bd72ff3'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 171,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a782bad625757dbd72fff'),
#   'ageScore': 0.03661383867800988,
#   'characterLength': 171,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a7ba9ad62575ffad73008'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 45,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a7ba9ad62572b68d73014'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 20,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a7baaad6257bcc3d73020'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 24,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a7baaad62570bcfd7302c'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 60,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a7baaad625754d7d73038'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 48,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a7badad625760a3d73044'),
#   'ageScore': 0.03687862006446663,
#   'characterLength': 45,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 27,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a7badad62571601d7304d'),
#   'ageScore': 0.03687863692849544,
#   'characterLength': 20,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 27,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a7badad6257847ed73056'),
#   'ageScore': 0.0368786481711856,
#   'characterLength': 24,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 27,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a7badad62571377d7305f'),
#   'ageScore': 0.036878669768994746,
#   'characterLength': 60,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 27,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a7badad625790a1d73068'),
#   'ageScore': 0.0368787212487552,
#   'characterLength': 48,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 27,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a7f2dad62572f52d73071'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 78,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a7f2dad62578a1ad7307d'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 54,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a7f2fad625766e6d73089'),
#   'ageScore': 0.03714515863686381,
#   'characterLength': 78,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 578,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a7f30ad6257e4aed73092'),
#   'ageScore': 0.037145512064650624,
#   'characterLength': 54,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a8635ad62573e16d730a1'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 99,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a8637ad62572b08d730ad'),
#   'ageScore': 0.03768554294785851,
#   'characterLength': 99,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 12,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a8d3fad62577b1cd730b6'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 277,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a8d44ad6257be78d730c2'),
#   'ageScore': 0.03823539142769254,
#   'characterLength': 277,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a91edad6257189fd730cb'),
#   'ageScore': 0.038602830664338325,
#   'characterLength': 204,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a9446ad6257b476d730d4'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 294,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a9448ad62571816d730e0'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 433,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a944bad6257b72dd730ec'),
#   'ageScore': 0.038791068394646896,
#   'characterLength': 294,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 9,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a944cad62574d64d730f5'),
#   'ageScore': 0.03879152524300954,
#   'characterLength': 433,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 9,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a97c9ad62578625d730fe'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 289,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a97cbad62577ef7d7310a'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 87,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a97cdad62572e96d73116'),
#   'ageScore': 0.03907167171415573,
#   'characterLength': 289,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a97cfad62579f86d7311f'),
#   'ageScore': 0.039072189543470665,
#   'characterLength': 87,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a9ed4ad6257f859d73128'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 39,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617a9ed8ad6257700ad73134'),
#   'ageScore': 0.039640718473240806,
#   'characterLength': 39,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617aa256ad62570fd0d7313d'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 88,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617aa257ad6257c24bd73149'),
#   'ageScore': 0.03992654508453628,
#   'characterLength': 88,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 578,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617aa95dad6257a21fd73152'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 69,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617aa95fad625738ebd7315e'),
#   'ageScore': 0.040507260808289265,
#   'characterLength': 69,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 578,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617aace3ad6257f868d73167'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 120,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617aace8ad6257096ad73173'),
#   'ageScore': 0.040802356129100804,
#   'characterLength': 120,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ab3ebad62571b0ed7317c'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 57,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ab3edad62571fa4d73188'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 100,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ab3efad6257750fd73194'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 286,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ab3f3ad6257f0ead731a0'),
#   'ageScore': 0.04139703464491854,
#   'characterLength': 57,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ab3f5ad62574937d731a9'),
#   'ageScore': 0.041397621153981164,
#   'characterLength': 100,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ab3f8ad6257559cd731b2'),
#   'ageScore': 0.04139841126058338,
#   'characterLength': 286,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617abc1dad625783ccd731bb'),
#   'ageScore': 0.04209684204562455,
#   'characterLength': 272,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617abe75ad625709e5d731c4'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 56,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617abe76ad62573103d731d0'),
#   'ageScore': 0.042300430873492195,
#   'characterLength': 56,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 578,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617abe7bad625728a7d731d9'),
#   'ageScore': 0.04230183956687463,
#   'characterLength': 118,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 56,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ac1fbad6257534fd731e2'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 292,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ac1fdad6257141ed731ee'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 118,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ac201ad62575a33d731fa'),
#   'ageScore': 0.04260925463932736,
#   'characterLength': 292,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ac902ad6257891dd73203'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 56,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ac904ad6257b839d7320f'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 286,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ac907ad62571736d7321b'),
#   'ageScore': 0.043228177441336835,
#   'characterLength': 56,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ac909ad6257ab10d73224'),
#   'ageScore': 0.04322882214668412,
#   'characterLength': 286,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617aca2cad62573a06d7322d'),
#   'ageScore': 0.043330195344743444,
#   'characterLength': 252,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617aca2dad62573de2d73236'),
#   'ageScore': 0.04333032570172226,
#   'characterLength': 107,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ad00cad62573813d7323f'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 66,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ad00cad62579cadd7324b'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 294,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ad011ad6257476dd73257'),
#   'ageScore': 0.04385770293570175,
#   'characterLength': 66,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ad011ad625755dbd73260'),
#   'ageScore': 0.04385771841710607,
#   'characterLength': 294,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ad38dad6257154ad73269'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 86,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ad38fad62575160d73275'),
#   'ageScore': 0.04417351657887985,
#   'characterLength': 86,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 578,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ad711ad62572626d7327e'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 59,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ad714ad6257a785d7328a'),
#   'ageScore': 0.044493991247170926,
#   'characterLength': 59,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ad83dad62573ed7d73293'),
#   'ageScore': 0.04460011351023265,
#   'characterLength': 173,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ade1bad625787e2d7329c'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 292,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ade1dad625777ced732a8'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 281,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ade21ad6257603ad732b4'),
#   'ageScore': 0.04514285707697283,
#   'characterLength': 292,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ade23ad62577547d732bd'),
#   'ageScore': 0.045143504986278636,
#   'characterLength': 281,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617adf45ad6257e564d732c6'),
#   'ageScore': 0.04524864797143546,
#   'characterLength': 164,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ae523ad625724add732cf'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 47,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ae525ad6257b38dd732db'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 120,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ae529ad62570049d732e7'),
#   'ageScore': 0.04579966317670352,
#   'characterLength': 47,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ae52bad625726b8d732f0'),
#   'ageScore': 0.045800246291006354,
#   'characterLength': 120,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ae8a5ad625765c6d732f9'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 74,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617ae8a7ad62577bf7d73305'),
#   'ageScore': 0.046129201572286574,
#   'characterLength': 74,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 578,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617aec2bad625776ffd7330e'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 117,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617aec2bad6257abedd7331a'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 267,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617aec30ad62577066d73326'),
#   'ageScore': 0.04646516064736768,
#   'characterLength': 117,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617aec30ad62570f78d7332f'),
#   'ageScore': 0.04646518114963759,
#   'characterLength': 267,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617af332ad62578885d73338'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 20,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617af335ad625760d8d73344'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 121,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617af339ad6257a3d8d73350'),
#   'ageScore': 0.047141561864109324,
#   'characterLength': 20,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617af33bad62574fcbd73359'),
#   'ageScore': 0.04714218551165003,
#   'characterLength': 121,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617afa3bad625775f3d73362'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 189,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617afa3fad6257033dd7336e'),
#   'ageScore': 0.04782654183877712,
#   'characterLength': 189,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617b0144ad62572d9bd73377'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 290,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617b0148ad62578bbcd73383'),
#   'ageScore': 0.048522653861517,
#   'characterLength': 290,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617b026cad6257006cd7338c'),
#   'ageScore': 0.04863648577353604,
#   'characterLength': 225,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617b04c5ad62577445d73395'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 88,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617b04c7ad62573c97d733a1'),
#   'ageScore': 0.04887215527179516,
#   'characterLength': 88,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 578,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617b0f51ad62575136d733aa'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 265,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617b0f53ad62576698d733b6'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 146,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617b0f55ad62573822d733c2'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 288,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617b0f57ad62571b65d733ce'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 264,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617b0f59ad625757b5d733da'),
#   'ageScore': 0.049944730580873516,
#   'characterLength': 265,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617b0f5bad6257668dd733e3'),
#   'ageScore': 0.04994540132945546,
#   'characterLength': 146,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617b0f5cad6257fffed733ec'),
#   'ageScore': 0.04994599755797949,
#   'characterLength': 288,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617b0f5ead625785f6d733f5'),
#   'ageScore': 0.049946773306821186,
#   'characterLength': 264,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617b107dad62575d17d733fe'),
#   'ageScore': 0.05006191066810922,
#   'characterLength': 286,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617b12d5ad625716c6d73407'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 102,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617b12d6ad62573d1ed73413'),
#   'ageScore': 0.050303970537479425,
#   'characterLength': 102,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 578,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617b1d62ad62572857d7341c'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 103,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617b1d64ad62571ee8d73428'),
#   'ageScore': 0.05140630886962437,
#   'characterLength': 103,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617b20e5ad6257cb17d73431'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 87,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617b20e7ad62570560d7343d'),
#   'ageScore': 0.05177832668472515,
#   'characterLength': 87,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 578,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617b246bad62575aa3d73446'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 218,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617b246bad62575201d73452'),
#   'ageScore': 0.5053877431399482,
#   'characterLength': 164,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617b246fad6257719bd7345e'),
#   'ageScore': 0.05215529864056984,
#   'characterLength': 218,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('617b246fad6257a441d73467'),
#   'ageScore': 0.052155319561464186,
#   'characterLength': 164,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
# ...
#   'recastCount': 0},
#  {'_id': ObjectId('6180b4427ea1b5a72ca629c8'),
#   'ageScore': 0.9711007007933857,
#   'characterLength': 355,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180b4457ea1b54e95a629d3'),
#   'ageScore': 0.9711247197911452,
#   'characterLength': 303,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180b4477ea1b53ae8a629de'),
#   'ageScore': 0.9711389850041804,
#   'characterLength': 142,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180b44b7ea1b54a40a629e9'),
#   'ageScore': 0.9711730088895678,
#   'characterLength': 303,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 578,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180b44d7ea1b55ecea629f2'),
#   'ageScore': 0.971188575974217,
#   'characterLength': 142,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 578,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180b4517ea1b51e7fa629fb'),
#   'ageScore': 0.9712150047493898,
#   'characterLength': 176,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180b4537ea1b5dc7fa62a04'),
#   'ageScore': 0.9712308530096265,
#   'characterLength': 355,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180b7c47ea1b5e1b0a62a0d'),
#   'ageScore': 0.978122073239791,
#   'characterLength': 316,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180b7c67ea1b57169a62a18'),
#   'ageScore': 0.9781363706153415,
#   'characterLength': 316,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180b7ca7ea1b5f9fda62a23'),
#   'ageScore': 0.9781652641933019,
#   'characterLength': 164,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180b7ce7ea1b50cf1a62a2e'),
#   'ageScore': 0.9781977214410355,
#   'characterLength': 152,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180b7d27ea1b56a54a62a39'),
#   'ageScore': 0.9782270798550565,
#   'characterLength': 164,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 578,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180b7d57ea1b57d9aa62a42'),
#   'ageScore': 0.9782555052269534,
#   'characterLength': 152,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 578,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180b7d97ea1b578cca62a4b'),
#   'ageScore': 0.9782845435938982,
#   'characterLength': 316,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180b7da7ea1b50141a62a54'),
#   'ageScore': 0.97829745417168,
#   'characterLength': 316,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180b8967ea1b51f31a62a5d'),
#   'ageScore': 0.9797679643626124,
#   'characterLength': 12,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180b8ec7ea1b540a4a62a68'),
#   'ageScore': 0.9804502413550117,
#   'characterLength': 210,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180bb497ea1b500aaa62a71'),
#   'ageScore': 0.985214596481805,
#   'characterLength': 156,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180bb4c7ea1b574bda62a7c'),
#   'ageScore': 0.9852372809944121,
#   'characterLength': 296,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180bb4e7ea1b54299a62a87'),
#   'ageScore': 0.9852549626300415,
#   'characterLength': 180,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180bb507ea1b5abb0a62a92'),
#   'ageScore': 0.9852719015709862,
#   'characterLength': 210,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180bb527ea1b51c88a62a9d'),
#   'ageScore': 0.9852883191052352,
#   'characterLength': 164,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180bb557ea1b5c6ada62aa8'),
#   'ageScore': 0.9853093058075979,
#   'characterLength': 224,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180bb587ea1b5513fa62ab3'),
#   'ageScore': 0.9853389329943214,
#   'characterLength': 156,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 578,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180bb5c7ea1b53898a62abc'),
#   'ageScore': 0.9853669009906344,
#   'characterLength': 296,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180bb5e7ea1b5f91fa62ac5'),
#   'ageScore': 0.9853819999279868,
#   'characterLength': 180,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180bb607ea1b5561ca62ace'),
#   'ageScore': 0.9854012494323064,
#   'characterLength': 210,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180bb627ea1b582faa62ad7'),
#   'ageScore': 0.9854169180949532,
#   'characterLength': 164,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180bb657ea1b5299fa62ae0'),
#   'ageScore': 0.9854387929766117,
#   'characterLength': 224,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180beca7ea1b54529a62ae9'),
#   'ageScore': 0.9923349838008293,
#   'characterLength': 100,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180becc7ea1b543aba62af4'),
#   'ageScore': 0.9923457551517353,
#   'characterLength': 158,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180becc7ea1b5e18ba62aff'),
#   'ageScore': 0.9923463681589616,
#   'characterLength': 233,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180bed07ea1b55067a62b0a'),
#   'ageScore': 0.9923837065858103,
#   'characterLength': 100,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180c24e7ea1b5435fa62b13'),
#   'ageScore': 0.9995265096937703,
#   'characterLength': 247,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180c2527ea1b52741a62b1e'),
#   'ageScore': 0.9995513680913592,
#   'characterLength': 316,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180c2547ea1b53cd9a62b29'),
#   'ageScore': 0.9995678471440609,
#   'characterLength': 309,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180c2567ea1b5a3f2a62b34'),
#   'ageScore': 0.9995851203697623,
#   'characterLength': 139,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180c2597ea1b514d7a62b3f'),
#   'ageScore': 0.9996088013727481,
#   'characterLength': 157,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180c25b7ea1b5b565a62b4a'),
#   'ageScore': 0.9996280240555545,
#   'characterLength': 181,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 1437,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180c25e7ea1b58f15a62b55'),
#   'ageScore': 0.9996514815221963,
#   'characterLength': 188,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 9,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 0,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180c2617ea1b56cb9a62b60'),
#   'ageScore': 0.9996747310211633,
#   'characterLength': 139,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 578,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180c2647ea1b522c8a62b69'),
#   'ageScore': 0.9997021836093508,
#   'characterLength': 157,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 578,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180c2677ea1b536d4a62b72'),
#   'ageScore': 0.9997210952961957,
#   'characterLength': 181,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 578,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180c26a7ea1b5576ba62b7b'),
#   'ageScore': 0.9997447554590729,
#   'characterLength': 247,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180c26c7ea1b57a49a62b84'),
#   'ageScore': 0.999760050648793,
#   'characterLength': 316,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0},
#  {'_id': ObjectId('6180c26e7ea1b5861fa62b8d'),
#   'ageScore': 0.9997759235655678,
#   'characterLength': 309,
#   'commentCount': 0,
#   'creatorCommentedCount': 0,
#   'creatorContentCount': 661,
#   'creatorLikedCount': 0,
#   'creatorQuotedCount': 0,
#   'creatorRecastedCount': 0,
#   'likeCount': 0,
#   'photoCount': 1,
#   'quoteCount': 0,
#   'recastCount': 0}]

# %%
content_features = pd.DataFrame(list(contentStats.aggregate(datasetCursor)))

# %%
content_features.head()
# Out:
#                         _id  likeCount  commentCount  recastCount  quoteCount  \
# 0  617a3fe741824b8714ae9be5          0             0            0           0
# 1  617a3fe941824b869eae9bf1          0             0            0           0
# 2  617a3fed41824b1eb9ae9bfd          0             0            0           0
# 3  617a3fef41824b762cae9c06          0             0            0           0
# 4  617a46ed41824b7404ae9c0f          0             0            0           0
#
#    photoCount  characterLength  creatorContentCount  creatorLikedCount  \
# 0           1              284                 1437                  0
# 1           1              201                 1437                  0
# 2           1              284                  661                  0
# 3           1              201                  661                  0
# 4           0               61                 1437                  0
#
#    creatorCommentedCount  creatorRecastedCount  creatorQuotedCount  ageScore
# 0                      0                     0                   0  0.505388
# 1                      0                     0                   0  0.505388
# 2                      0                     0                   0  0.032620
# 3                      0                     0                   0  0.032620
# 4                      0                     0                   0  0.505388
